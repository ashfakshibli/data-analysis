# %% [markdown]
# # Group By

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
oo = pd.read_csv("data/olympics.csv", skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.groupby('Edition')

# %%
list(oo.groupby('Edition'))
# Out:
# [(1896,
#          City  Edition          Sport       Discipline  \
#   0    Athens     1896       Aquatics         Swimming
#   1    Athens     1896       Aquatics         Swimming
#   2    Athens     1896       Aquatics         Swimming
#   3    Athens     1896       Aquatics         Swimming
#   4    Athens     1896       Aquatics         Swimming
#   5    Athens     1896       Aquatics         Swimming
#   6    Athens     1896       Aquatics         Swimming
#   7    Athens     1896       Aquatics         Swimming
#   8    Athens     1896       Aquatics         Swimming
#   9    Athens     1896       Aquatics         Swimming
#   10   Athens     1896       Aquatics         Swimming
#   11   Athens     1896      Athletics        Athletics
#   12   Athens     1896      Athletics        Athletics
#   13   Athens     1896      Athletics        Athletics
#   14   Athens     1896      Athletics        Athletics
#   15   Athens     1896      Athletics        Athletics
#   16   Athens     1896      Athletics        Athletics
#   17   Athens     1896      Athletics        Athletics
#   18   Athens     1896      Athletics        Athletics
#   19   Athens     1896      Athletics        Athletics
#   20   Athens     1896      Athletics        Athletics
#   21   Athens     1896      Athletics        Athletics
#   22   Athens     1896      Athletics        Athletics
#   23   Athens     1896      Athletics        Athletics
#   24   Athens     1896      Athletics        Athletics
#   25   Athens     1896      Athletics        Athletics
#   26   Athens     1896      Athletics        Athletics
#   27   Athens     1896      Athletics        Athletics
#   28   Athens     1896      Athletics        Athletics
#   29   Athens     1896      Athletics        Athletics
#   30   Athens     1896      Athletics        Athletics
#   31   Athens     1896      Athletics        Athletics
#   32   Athens     1896      Athletics        Athletics
#   33   Athens     1896      Athletics        Athletics
#   34   Athens     1896      Athletics        Athletics
#   35   Athens     1896      Athletics        Athletics
#   36   Athens     1896      Athletics        Athletics
#   37   Athens     1896      Athletics        Athletics
#   38   Athens     1896      Athletics        Athletics
#   39   Athens     1896      Athletics        Athletics
#   40   Athens     1896      Athletics        Athletics
#   41   Athens     1896      Athletics        Athletics
#   42   Athens     1896      Athletics        Athletics
#   43   Athens     1896      Athletics        Athletics
#   44   Athens     1896      Athletics        Athletics
#   45   Athens     1896      Athletics        Athletics
#   46   Athens     1896      Athletics        Athletics
#   47   Athens     1896      Athletics        Athletics
#   48   Athens     1896        Cycling     Cycling Road
#   49   Athens     1896        Cycling     Cycling Road
#   50   Athens     1896        Cycling     Cycling Road
#   51   Athens     1896        Cycling    Cycling Track
#   52   Athens     1896        Cycling    Cycling Track
#   53   Athens     1896        Cycling    Cycling Track
#   54   Athens     1896        Cycling    Cycling Track
#   55   Athens     1896        Cycling    Cycling Track
#   56   Athens     1896        Cycling    Cycling Track
#   57   Athens     1896        Cycling    Cycling Track
#   58   Athens     1896        Cycling    Cycling Track
#   59   Athens     1896        Cycling    Cycling Track
#   60   Athens     1896        Cycling    Cycling Track
#   61   Athens     1896        Cycling    Cycling Track
#   62   Athens     1896        Cycling    Cycling Track
#   63   Athens     1896        Cycling    Cycling Track
#   64   Athens     1896        Fencing          Fencing
#   65   Athens     1896        Fencing          Fencing
#   66   Athens     1896        Fencing          Fencing
#   67   Athens     1896        Fencing          Fencing
#   68   Athens     1896        Fencing          Fencing
#   69   Athens     1896        Fencing          Fencing
#   70   Athens     1896        Fencing          Fencing
#   71   Athens     1896        Fencing          Fencing
#   72   Athens     1896     Gymnastics      Artistic G.
#   73   Athens     1896     Gymnastics      Artistic G.
#   74   Athens     1896     Gymnastics      Artistic G.
#   75   Athens     1896     Gymnastics      Artistic G.
#   76   Athens     1896     Gymnastics      Artistic G.
#   77   Athens     1896     Gymnastics      Artistic G.
#   78   Athens     1896     Gymnastics      Artistic G.
#   79   Athens     1896     Gymnastics      Artistic G.
#   80   Athens     1896     Gymnastics      Artistic G.
#   81   Athens     1896     Gymnastics      Artistic G.
#   82   Athens     1896     Gymnastics      Artistic G.
#   83   Athens     1896     Gymnastics      Artistic G.
#   84   Athens     1896     Gymnastics      Artistic G.
#   85   Athens     1896     Gymnastics      Artistic G.
#   86   Athens     1896     Gymnastics      Artistic G.
#   87   Athens     1896     Gymnastics      Artistic G.
#   88   Athens     1896     Gymnastics      Artistic G.
#   89   Athens     1896     Gymnastics      Artistic G.
#   90   Athens     1896     Gymnastics      Artistic G.
#   91   Athens     1896     Gymnastics      Artistic G.
#   92   Athens     1896     Gymnastics      Artistic G.
#   93   Athens     1896     Gymnastics      Artistic G.
#   94   Athens     1896     Gymnastics      Artistic G.
#   95   Athens     1896     Gymnastics      Artistic G.
#   96   Athens     1896     Gymnastics      Artistic G.
#   97   Athens     1896     Gymnastics      Artistic G.
#   98   Athens     1896     Gymnastics      Artistic G.
#   99   Athens     1896     Gymnastics      Artistic G.
#   100  Athens     1896     Gymnastics      Artistic G.
#   101  Athens     1896     Gymnastics      Artistic G.
#   102  Athens     1896     Gymnastics      Artistic G.
#   103  Athens     1896     Gymnastics      Artistic G.
#   104  Athens     1896     Gymnastics      Artistic G.
#   105  Athens     1896     Gymnastics      Artistic G.
#   106  Athens     1896     Gymnastics      Artistic G.
#   107  Athens     1896     Gymnastics      Artistic G.
#   108  Athens     1896     Gymnastics      Artistic G.
#   109  Athens     1896     Gymnastics      Artistic G.
#   110  Athens     1896     Gymnastics      Artistic G.
#   111  Athens     1896     Gymnastics      Artistic G.
#   112  Athens     1896     Gymnastics      Artistic G.
#   113  Athens     1896     Gymnastics      Artistic G.
#   114  Athens     1896     Gymnastics      Artistic G.
#   115  Athens     1896     Gymnastics      Artistic G.
#   116  Athens     1896     Gymnastics      Artistic G.
#   117  Athens     1896       Shooting         Shooting
#   118  Athens     1896       Shooting         Shooting
#   119  Athens     1896       Shooting         Shooting
#   120  Athens     1896       Shooting         Shooting
#   121  Athens     1896       Shooting         Shooting
#   122  Athens     1896       Shooting         Shooting
#   123  Athens     1896       Shooting         Shooting
#   124  Athens     1896       Shooting         Shooting
#   125  Athens     1896       Shooting         Shooting
#   126  Athens     1896       Shooting         Shooting
#   127  Athens     1896       Shooting         Shooting
#   128  Athens     1896       Shooting         Shooting
#   129  Athens     1896       Shooting         Shooting
#   130  Athens     1896       Shooting         Shooting
#   131  Athens     1896       Shooting         Shooting
#   132  Athens     1896         Tennis           Tennis
#   133  Athens     1896         Tennis           Tennis
#   134  Athens     1896         Tennis           Tennis
#   135  Athens     1896         Tennis           Tennis
#   136  Athens     1896         Tennis           Tennis
#   137  Athens     1896         Tennis           Tennis
#   138  Athens     1896         Tennis           Tennis
#   139  Athens     1896         Tennis           Tennis
#   140  Athens     1896         Tennis           Tennis
#   141  Athens     1896         Tennis           Tennis
#   142  Athens     1896  Weightlifting    Weightlifting
#   143  Athens     1896  Weightlifting    Weightlifting
#   144  Athens     1896  Weightlifting    Weightlifting
#   145  Athens     1896  Weightlifting    Weightlifting
#   146  Athens     1896  Weightlifting    Weightlifting
#   147  Athens     1896  Weightlifting    Weightlifting
#   148  Athens     1896      Wrestling  Wrestling Gre-R
#   149  Athens     1896      Wrestling  Wrestling Gre-R
#   150  Athens     1896      Wrestling  Wrestling Gre-R
#
#                                  Athlete  NOC Gender  \
#   0                        HAJOS, Alfred  HUN    Men
#   1                     HERSCHMANN, Otto  AUT    Men
#   2                    DRIVAS, Dimitrios  GRE    Men
#   3                   MALOKINIS, Ioannis  GRE    Men
#   4                   CHASAPIS, Spiridon  GRE    Men
#   5                CHOROPHAS, Efstathios  GRE    Men
#   6                        HAJOS, Alfred  HUN    Men
#   7                     ANDREOU, Joannis  GRE    Men
#   8                CHOROPHAS, Efstathios  GRE    Men
#   9                        NEUMANN, Paul  AUT    Men
#   10                   PEPANOS, Antonios  GRE    Men
#   11                       LANE, Francis  USA    Men
#   12                    SZOKOLYI, Alajos  HUN    Men
#   13                       BURKE, Thomas  USA    Men
#   14                      HOFMANN, Fritz  GER    Men
#   15                      CURTIS, Thomas  USA    Men
#   16                  GOULDING, Grantley  GBR    Men
#   17                   LERMUSIAUX, Albin  FRA    Men
#   18                        FLACK, Edwin  AUS    Men
#   19                       BLAKE, Arthur  USA    Men
#   20                     GMELIN, Charles  GBR    Men
#   21                       BURKE, Thomas  USA    Men
#   22                    JAMISON, Herbert  USA    Men
#   23                  GOLEMIS, Dimitrios  GRE    Men
#   24                        FLACK, Edwin  AUS    Men
#   25                        DANI, Nandor  HUN    Men
#   26                    VERSIS, Sotirios  GRE    Men
#   27                     GARRETT, Robert  USA    Men
#   28         PARASKEVOPOULOS, Panagiotis  GRE    Men
#   29                       CLARK, Ellery  USA    Men
#   30                     CONNOLLY, James  USA    Men
#   31                     GARRETT, Robert  USA    Men
#   32                     CONNOLLY, James  USA    Men
#   33                       CLARK, Ellery  USA    Men
#   34                     GARRETT, Robert  USA    Men
#   35                      KELLNER, Gyula  HUN    Men
#   36                     LOUIS, Spyridon  GRE    Men
#   37                VASILAKOS, Kharilaos  GRE    Men
#   38                 DAMASKOS, Evangelos  GRE    Men
#   39             THEODOROPOULOS, Ioannis  GRE    Men
#   40                HOYT, William Welles  USA    Men
#   41                       TYLER, Albert  USA    Men
#   42               PAPASIDERIS, Georgios  GRE    Men
#   43                     GARRETT, Robert  USA    Men
#   44                  GOUSKOS, Miltiadis  GRE    Men
#   45                   PERSAKIS, Ioannis  GRE    Men
#   46                     CONNOLLY, James  USA    Men
#   47                  TUFFERI, Alexandre  FRA    Men
#   48                      BATTEL, Edward  GBR    Men
#   49           KONSTANTINIDIS, Aristidis  GRE    Men
#   50                    GOEDRICH, August  GER    Men
#   51                       FLAMENG, Léon  FRA    Men
#   52                  KOLETTIS, Georgios  GRE    Men
#   53                       SCHMAL, Adolf  AUT    Men
#   54                        MASSON, Paul  FRA    Men
#   55                       FLAMENG, Léon  FRA    Men
#   56                       SCHMAL, Adolf  AUT    Men
#   57                      KEEPING, Frank  GBR    Men
#   58                       SCHMAL, Adolf  AUT    Men
#   59                        MASSON, Paul  FRA    Men
#   60             NIKOLOPOULOS, Stamatios  GRE    Men
#   61                       FLAMENG, Léon  FRA    Men
#   62                        MASSON, Paul  FRA    Men
#   63             NIKOLOPOULOS, Stamatios  GRE    Men
#   64   PIERRAKOS-MAVROMICHALIS, Perikles  GRE    Men
#   65            GRAVELOTTE, Eugène-Henri  FRA    Men
#   66                       CALLOT, Henri  FRA    Men
#   67                    PYRGOS, Leonidas  GRE    Men
#   68                  PERRONNET, Maurice  FRA    Men
#   69                     NIELSEN, Holger  DEN    Men
#   70                 GEORGIADIS, Ioannis  GRE    Men
#   71               KARAKALOS, Telemachos  GRE    Men
#   72                WEINGÄRTNER, Hermann  GER    Men
#   73                      FLATOW, Alfred  GER    Men
#   74                      FLATOW, Alfred  GER    Men
#   75                       ZUTTER, Louis  SUI    Men
#   76                       ZUTTER, Louis  SUI    Men
#   77                WEINGÄRTNER, Hermann  GER    Men
#   78                    PERSAKIS, Petros  GRE    Men
#   79                MITROPOULOS, Ioannis  GRE    Men
#   80                WEINGÄRTNER, Hermann  GER    Men
#   81                      HOFMANN, Fritz  GER    Men
#   82            ANDRIAKOPOULOS, Nicolaos  GRE    Men
#   83                  XENAKIS, Thomasios  GRE    Men
#   84                      BÖCKER, Konrad  GER    Men
#   85                      FLATOW, Alfred  GER    Men
#   86                FLATOW, Gustav Felix  GER    Men
#   87                       HILMAR, Georg  GER    Men
#   88                      HOFMANN, Fritz  GER    Men
#   89                   MANTEUFFEL, Fritz  GER    Men
#   90                      NEUKIRCH, Karl  GER    Men
#   91                     RÖSTEL, Richard  GER    Men
#   92                      SCHUFT, Gustav  GER    Men
#   93                      SCHUMANN, Carl  GER    Men
#   94                WEINGÄRTNER, Hermann  GER    Men
#   95                 CHRYSAPHIS, Ioannis  GRE    Men
#   96                KARVELAS, Phillippos  GRE    Men
#   97                 LOUNDRAS, Dimitrios  GRE    Men
#   98                MITROPOULOS, Ioannis  GRE    Men
#   99                      BÖCKER, Konrad  GER    Men
#   100                     FLATOW, Alfred  GER    Men
#   101               FLATOW, Gustav Felix  GER    Men
#   102                      HILMAR, Georg  GER    Men
#   103                     HOFMANN, Fritz  GER    Men
#   104                  MANTEUFFEL, Fritz  GER    Men
#   105                     NEUKIRCH, Karl  GER    Men
#   106                    RÖSTEL, Richard  GER    Men
#   107                     SCHUFT, Gustav  GER    Men
#   108                     SCHUMANN, Carl  GER    Men
#   109               WEINGÄRTNER, Hermann  GER    Men
#   110           ANDRIAKOPOULOS, Nicolaos  GRE    Men
#   111             ATHANASOPOULOS, Spyros  GRE    Men
#   112                   PERSAKIS, Petros  GRE    Men
#   113                 XENAKIS, Thomasios  GRE    Men
#   114               WEINGÄRTNER, Hermann  GER    Men
#   115                     SCHUMANN, Carl  GER    Men
#   116                      ZUTTER, Louis  SUI    Men
#   117                  MORAKIS, Nikolaos  GRE    Men
#   118                        PAINE, John  USA    Men
#   119                      PAINE, Sumner  USA    Men
#   120                    NIELSEN, Holger  DEN    Men
#   121               PHRANGOUDIS, Joannis  GRE    Men
#   122               ORPHANIDIS, Georgios  GRE    Men
#   123               PHRANGOUDIS, Joannis  GRE    Men
#   124                      PAINE, Sumner  USA    Men
#   125                    NIELSEN, Holger  DEN    Men
#   126                 TRIKUPIS, Nicolaos  GRE    Men
#   127               KARASEVDAS, Pantelis  GRE    Men
#   128                   PAVLIDIS, Pavlos  GRE    Men
#   129                      JENSEN, Viggo  DEN    Men
#   130               ORPHANIDIS, Georgios  GRE    Men
#   131               PHRANGOUDIS, Joannis  GRE    Men
#   132                       FLACK, Edwin  ZZX    Men
#   133           ROBERTSON, George Stuart  ZZX    Men
#   134                       BOLAND, John  ZZX    Men
#   135                   TRAUN, Friedrich  ZZX    Men
#   136               KASDAGLIS, Dionysios  ZZX    Men
#   137           PETROKOKKINOS, Demetrios  ZZX    Men
#   138             PASPATIS, Konstantinos  GRE    Men
#   139               TAPAVICZA, Momcsillo  HUN    Men
#   140                       BOLAND, John  GBR    Men
#   141               KASDAGLIS, Dionysios  GRE    Men
#   142           NIKOLOPOULOS, Alexandros  GRE    Men
#   143                ELLIOTT, Launceston  GBR    Men
#   144                      JENSEN, Viggo  DEN    Men
#   145                   VERSIS, Sotirios  GRE    Men
#   146                      JENSEN, Viggo  DEN    Men
#   147                ELLIOTT, Launceston  GBR    Men
#   148           CHRISTOPOULOS, Stephanos  GRE    Men
#   149                     SCHUMANN, Carl  GER    Men
#   150                   TSITAS, Georgios  GRE    Men
#
#                                   Event Event_gender   Medal
#   0                      100m freestyle            M    Gold
#   1                      100m freestyle            M  Silver
#   2          100m freestyle for sailors            M  Bronze
#   3          100m freestyle for sailors            M    Gold
#   4          100m freestyle for sailors            M  Silver
#   5                     1200m freestyle            M  Bronze
#   6                     1200m freestyle            M    Gold
#   7                     1200m freestyle            M  Silver
#   8                      400m freestyle            M  Bronze
#   9                      400m freestyle            M    Gold
#   10                     400m freestyle            M  Silver
#   11                               100m            M  Bronze
#   12                               100m            M  Bronze
#   13                               100m            M    Gold
#   14                               100m            M  Silver
#   15                       110m hurdles            M    Gold
#   16                       110m hurdles            M  Silver
#   17                              1500m            M  Bronze
#   18                              1500m            M    Gold
#   19                              1500m            M  Silver
#   20                               400m            M  Bronze
#   21                               400m            M    Gold
#   22                               400m            M  Silver
#   23                               800m            M  Bronze
#   24                               800m            M    Gold
#   25                               800m            M  Silver
#   26                       discus throw            M  Bronze
#   27                       discus throw            M    Gold
#   28                       discus throw            M  Silver
#   29                          high jump            M    Gold
#   30                          high jump            M  Silver
#   31                          high jump            M  Silver
#   32                          long jump            M  Bronze
#   33                          long jump            M    Gold
#   34                          long jump            M  Silver
#   35                           marathon            M  Bronze
#   36                           marathon            M    Gold
#   37                           marathon            M  Silver
#   38                         pole vault            M  Bronze
#   39                         pole vault            M  Bronze
#   40                         pole vault            M    Gold
#   41                         pole vault            M  Silver
#   42                           shot put            M  Bronze
#   43                           shot put            M    Gold
#   44                           shot put            M  Silver
#   45                        triple jump            M  Bronze
#   46                        triple jump            M    Gold
#   47                        triple jump            M  Silver
#   48               individual road race            M  Bronze
#   49               individual road race            M    Gold
#   50               individual road race            M  Silver
#   51                              100km            M    Gold
#   52                              100km            M  Silver
#   53                               10km            M  Bronze
#   54                               10km            M    Gold
#   55                               10km            M  Silver
#   56                       12-hour race            M    Gold
#   57                       12-hour race            M  Silver
#   58                     1km time trial            M  Bronze
#   59                     1km time trial            M    Gold
#   60                     1km time trial            M  Silver
#   61                    Sprint indivual            M  Bronze
#   62                    Sprint indivual            M    Gold
#   63                    Sprint indivual            M  Silver
#   64                    foil individual            M  Bronze
#   65                    foil individual            M    Gold
#   66                    foil individual            M  Silver
#   67                      foil, masters            M    Gold
#   68                      foil, masters            M  Silver
#   69                   sabre individual            M  Bronze
#   70                   sabre individual            M    Gold
#   71                   sabre individual            M  Silver
#   72                     horizontal bar            M    Gold
#   73                     horizontal bar            M  Silver
#   74                      parallel bars            M    Gold
#   75                      parallel bars            M  Silver
#   76                       pommel horse            M    Gold
#   77                       pommel horse            M  Silver
#   78                              rings            M  Bronze
#   79                              rings            M    Gold
#   80                              rings            M  Silver
#   81                      rope climbing            M  Bronze
#   82                      rope climbing            M    Gold
#   83                      rope climbing            M  Silver
#   84               team, horizontal bar            M    Gold
#   85               team, horizontal bar            M    Gold
#   86               team, horizontal bar            M    Gold
#   87               team, horizontal bar            M    Gold
#   88               team, horizontal bar            M    Gold
#   89               team, horizontal bar            M    Gold
#   90               team, horizontal bar            M    Gold
#   91               team, horizontal bar            M    Gold
#   92               team, horizontal bar            M    Gold
#   93               team, horizontal bar            M    Gold
#   94               team, horizontal bar            M    Gold
#   95                team, parallel bars            M  Bronze
#   96                team, parallel bars            M  Bronze
#   97                team, parallel bars            M  Bronze
#   98                team, parallel bars            M  Bronze
#   99                team, parallel bars            M    Gold
#   100               team, parallel bars            M    Gold
#   101               team, parallel bars            M    Gold
#   102               team, parallel bars            M    Gold
#   103               team, parallel bars            M    Gold
#   104               team, parallel bars            M    Gold
#   105               team, parallel bars            M    Gold
#   106               team, parallel bars            M    Gold
#   107               team, parallel bars            M    Gold
#   108               team, parallel bars            M    Gold
#   109               team, parallel bars            M    Gold
#   110               team, parallel bars            M  Silver
#   111               team, parallel bars            M  Silver
#   112               team, parallel bars            M  Silver
#   113               team, parallel bars            M  Silver
#   114                             vault            M  Bronze
#   115                             vault            M    Gold
#   116                             vault            M  Silver
#   117                   25m army pistol            M  Bronze
#   118                   25m army pistol            M    Gold
#   119                   25m army pistol            M  Silver
#   120  25m rapid fire pistol (60 shots)            M  Bronze
#   121  25m rapid fire pistol (60 shots)            M    Gold
#   122  25m rapid fire pistol (60 shots)            M  Silver
#   123             50m pistol (60 shots)            M  Bronze
#   124             50m pistol (60 shots)            M    Gold
#   125             50m pistol (60 shots)            M  Silver
#   126                  army rifle, 200m            M  Bronze
#   127                  army rifle, 200m            M    Gold
#   128                  army rifle, 200m            M  Silver
#   129                  army rifle, 300m            M  Bronze
#   130                  army rifle, 300m            M    Gold
#   131                  army rifle, 300m            M  Silver
#   132                           doubles            M  Bronze
#   133                           doubles            M  Bronze
#   134                           doubles            M    Gold
#   135                           doubles            M    Gold
#   136                           doubles            M  Silver
#   137                           doubles            M  Silver
#   138                           singles            M  Bronze
#   139                           singles            M  Bronze
#   140                           singles            M    Gold
#   141                           singles            M  Silver
#   142       heavyweight - one hand lift            M  Bronze
#   143       heavyweight - one hand lift            M    Gold
#   144       heavyweight - one hand lift            M  Silver
#   145       heavyweight - two hand lift            M  Bronze
#   146       heavyweight - two hand lift            M    Gold
#   147       heavyweight - two hand lift            M  Silver
#   148                        open event            M  Bronze
#   149                        open event            M    Gold
#   150                        open event            M  Silver  ),
#  (1900,
#         City  Edition       Sport  Discipline  \
#   151  Paris     1900    Aquatics    Swimming
#   152  Paris     1900    Aquatics    Swimming
#   153  Paris     1900    Aquatics    Swimming
#   154  Paris     1900    Aquatics    Swimming
#   155  Paris     1900    Aquatics    Swimming
#   ..     ...      ...         ...         ...
#   658  Paris     1900  Tug of War  Tug of War
#   659  Paris     1900  Tug of War  Tug of War
#   660  Paris     1900  Tug of War  Tug of War
#   661  Paris     1900  Tug of War  Tug of War
#   662  Paris     1900  Tug of War  Tug of War
#
#                                  Athlete  NOC Gender            Event  \
#   151                     HALMAY, Zoltan  HUN    Men  1500m freestyle
#   152                JARVIS, John Arthur  GBR    Men  1500m freestyle
#   153                        WAHLE, Otto  AUT    Men  1500m freestyle
#   154                    DROST, Johannes  NED    Men  200m backstroke
#   155                  HOPPENBERG, Ernst  GER    Men  200m backstroke
#   ..                                 ...  ...    ...              ...
#   658                       COLLAS, Jean  FRA    Men       tug of war
#   659                  GONDOUIN, Charles  FRA    Men       tug of war
#   660  HENRIQUEZ DE ZUBIERRA, Constantin  FRA    Men       tug of war
#   661                      ROFFO, Joseph  FRA    Men       tug of war
#   662                     SARRADE, Emile  FRA    Men       tug of war
#
#       Event_gender   Medal
#   151            M  Bronze
#   152            M    Gold
#   153            M  Silver
#   154            M  Bronze
#   155            M    Gold
#   ..           ...     ...
#   658            M  Silver
#   659            M  Silver
#   660            M  Silver
#   661            M  Silver
#   662            M  Silver
#
#   [512 rows x 10 columns]),
#  (1904,
#             City  Edition          Sport       Discipline  \
#   663   St Louis     1904       Aquatics           Diving
#   664   St Louis     1904       Aquatics           Diving
#   665   St Louis     1904       Aquatics           Diving
#   666   St Louis     1904       Aquatics           Diving
#   667   St Louis     1904       Aquatics           Diving
#   668   St Louis     1904       Aquatics           Diving
#   669   St Louis     1904       Aquatics           Diving
#   670   St Louis     1904       Aquatics         Swimming
#   671   St Louis     1904       Aquatics         Swimming
#   672   St Louis     1904       Aquatics         Swimming
#   673   St Louis     1904       Aquatics         Swimming
#   674   St Louis     1904       Aquatics         Swimming
#   675   St Louis     1904       Aquatics         Swimming
#   676   St Louis     1904       Aquatics         Swimming
#   677   St Louis     1904       Aquatics         Swimming
#   678   St Louis     1904       Aquatics         Swimming
#   679   St Louis     1904       Aquatics         Swimming
#   680   St Louis     1904       Aquatics         Swimming
#   681   St Louis     1904       Aquatics         Swimming
#   682   St Louis     1904       Aquatics         Swimming
#   683   St Louis     1904       Aquatics         Swimming
#   684   St Louis     1904       Aquatics         Swimming
#   685   St Louis     1904       Aquatics         Swimming
#   686   St Louis     1904       Aquatics         Swimming
#   687   St Louis     1904       Aquatics         Swimming
#   688   St Louis     1904       Aquatics         Swimming
#   689   St Louis     1904       Aquatics         Swimming
#   690   St Louis     1904       Aquatics         Swimming
#   691   St Louis     1904       Aquatics         Swimming
#   692   St Louis     1904       Aquatics         Swimming
#   693   St Louis     1904       Aquatics         Swimming
#   694   St Louis     1904       Aquatics         Swimming
#   695   St Louis     1904       Aquatics         Swimming
#   696   St Louis     1904       Aquatics         Swimming
#   697   St Louis     1904       Aquatics         Swimming
#   698   St Louis     1904       Aquatics         Swimming
#   699   St Louis     1904       Aquatics         Swimming
#   700   St Louis     1904       Aquatics         Swimming
#   701   St Louis     1904       Aquatics         Swimming
#   702   St Louis     1904       Aquatics         Swimming
#   703   St Louis     1904       Aquatics         Swimming
#   704   St Louis     1904       Aquatics         Swimming
#   705   St Louis     1904       Aquatics         Swimming
#   706   St Louis     1904        Archery          Archery
#   707   St Louis     1904        Archery          Archery
#   708   St Louis     1904        Archery          Archery
#   709   St Louis     1904        Archery          Archery
#   710   St Louis     1904        Archery          Archery
#   711   St Louis     1904        Archery          Archery
#   712   St Louis     1904        Archery          Archery
#   713   St Louis     1904        Archery          Archery
#   714   St Louis     1904        Archery          Archery
#   715   St Louis     1904        Archery          Archery
#   716   St Louis     1904        Archery          Archery
#   717   St Louis     1904        Archery          Archery
#   718   St Louis     1904        Archery          Archery
#   719   St Louis     1904        Archery          Archery
#   720   St Louis     1904        Archery          Archery
#   721   St Louis     1904        Archery          Archery
#   722   St Louis     1904        Archery          Archery
#   723   St Louis     1904        Archery          Archery
#   724   St Louis     1904        Archery          Archery
#   725   St Louis     1904        Archery          Archery
#   726   St Louis     1904        Archery          Archery
#   727   St Louis     1904        Archery          Archery
#   728   St Louis     1904        Archery          Archery
#   729   St Louis     1904        Archery          Archery
#   730   St Louis     1904        Archery          Archery
#   731   St Louis     1904        Archery          Archery
#   732   St Louis     1904        Archery          Archery
#   733   St Louis     1904        Archery          Archery
#   734   St Louis     1904        Archery          Archery
#   735   St Louis     1904        Archery          Archery
#   736   St Louis     1904      Athletics        Athletics
#   737   St Louis     1904      Athletics        Athletics
#   738   St Louis     1904      Athletics        Athletics
#   739   St Louis     1904      Athletics        Athletics
#   740   St Louis     1904      Athletics        Athletics
#   741   St Louis     1904      Athletics        Athletics
#   742   St Louis     1904      Athletics        Athletics
#   743   St Louis     1904      Athletics        Athletics
#   744   St Louis     1904      Athletics        Athletics
#   745   St Louis     1904      Athletics        Athletics
#   746   St Louis     1904      Athletics        Athletics
#   747   St Louis     1904      Athletics        Athletics
#   748   St Louis     1904      Athletics        Athletics
#   749   St Louis     1904      Athletics        Athletics
#   750   St Louis     1904      Athletics        Athletics
#   751   St Louis     1904      Athletics        Athletics
#   752   St Louis     1904      Athletics        Athletics
#   753   St Louis     1904      Athletics        Athletics
#   754   St Louis     1904      Athletics        Athletics
#   755   St Louis     1904      Athletics        Athletics
#   756   St Louis     1904      Athletics        Athletics
#   757   St Louis     1904      Athletics        Athletics
#   758   St Louis     1904      Athletics        Athletics
#   759   St Louis     1904      Athletics        Athletics
#   760   St Louis     1904      Athletics        Athletics
#   761   St Louis     1904      Athletics        Athletics
#   762   St Louis     1904      Athletics        Athletics
#   763   St Louis     1904      Athletics        Athletics
#   764   St Louis     1904      Athletics        Athletics
#   765   St Louis     1904      Athletics        Athletics
#   766   St Louis     1904      Athletics        Athletics
#   767   St Louis     1904      Athletics        Athletics
#   768   St Louis     1904      Athletics        Athletics
#   769   St Louis     1904      Athletics        Athletics
#   770   St Louis     1904      Athletics        Athletics
#   771   St Louis     1904      Athletics        Athletics
#   772   St Louis     1904      Athletics        Athletics
#   773   St Louis     1904      Athletics        Athletics
#   774   St Louis     1904      Athletics        Athletics
#   775   St Louis     1904      Athletics        Athletics
#   776   St Louis     1904      Athletics        Athletics
#   777   St Louis     1904      Athletics        Athletics
#   778   St Louis     1904      Athletics        Athletics
#   779   St Louis     1904      Athletics        Athletics
#   780   St Louis     1904      Athletics        Athletics
#   781   St Louis     1904      Athletics        Athletics
#   782   St Louis     1904      Athletics        Athletics
#   783   St Louis     1904      Athletics        Athletics
#   784   St Louis     1904      Athletics        Athletics
#   785   St Louis     1904      Athletics        Athletics
#   786   St Louis     1904      Athletics        Athletics
#   787   St Louis     1904      Athletics        Athletics
#   788   St Louis     1904      Athletics        Athletics
#   789   St Louis     1904      Athletics        Athletics
#   790   St Louis     1904      Athletics        Athletics
#   791   St Louis     1904      Athletics        Athletics
#   792   St Louis     1904      Athletics        Athletics
#   793   St Louis     1904      Athletics        Athletics
#   794   St Louis     1904      Athletics        Athletics
#   795   St Louis     1904      Athletics        Athletics
#   796   St Louis     1904      Athletics        Athletics
#   797   St Louis     1904      Athletics        Athletics
#   798   St Louis     1904      Athletics        Athletics
#   799   St Louis     1904      Athletics        Athletics
#   800   St Louis     1904      Athletics        Athletics
#   801   St Louis     1904      Athletics        Athletics
#   802   St Louis     1904      Athletics        Athletics
#   803   St Louis     1904      Athletics        Athletics
#   804   St Louis     1904      Athletics        Athletics
#   805   St Louis     1904      Athletics        Athletics
#   806   St Louis     1904      Athletics        Athletics
#   807   St Louis     1904      Athletics        Athletics
#   808   St Louis     1904      Athletics        Athletics
#   809   St Louis     1904      Athletics        Athletics
#   810   St Louis     1904      Athletics        Athletics
#   811   St Louis     1904      Athletics        Athletics
#   812   St Louis     1904      Athletics        Athletics
#   813   St Louis     1904      Athletics        Athletics
#   814   St Louis     1904      Athletics        Athletics
#   815   St Louis     1904      Athletics        Athletics
#   816   St Louis     1904      Athletics        Athletics
#   817   St Louis     1904      Athletics        Athletics
#   818   St Louis     1904         Boxing           Boxing
#   819   St Louis     1904         Boxing           Boxing
#   820   St Louis     1904         Boxing           Boxing
#   821   St Louis     1904         Boxing           Boxing
#   822   St Louis     1904         Boxing           Boxing
#   823   St Louis     1904         Boxing           Boxing
#   824   St Louis     1904         Boxing           Boxing
#   825   St Louis     1904         Boxing           Boxing
#   826   St Louis     1904         Boxing           Boxing
#   827   St Louis     1904         Boxing           Boxing
#   828   St Louis     1904         Boxing           Boxing
#   829   St Louis     1904         Boxing           Boxing
#   830   St Louis     1904         Boxing           Boxing
#   831   St Louis     1904         Boxing           Boxing
#   832   St Louis     1904         Boxing           Boxing
#   833   St Louis     1904         Boxing           Boxing
#   834   St Louis     1904         Boxing           Boxing
#   835   St Louis     1904         Boxing           Boxing
#   836   St Louis     1904         Boxing           Boxing
#   837   St Louis     1904        Cycling    Cycling Track
#   838   St Louis     1904        Cycling    Cycling Track
#   839   St Louis     1904        Cycling    Cycling Track
#   840   St Louis     1904        Cycling    Cycling Track
#   841   St Louis     1904        Cycling    Cycling Track
#   842   St Louis     1904        Cycling    Cycling Track
#   843   St Louis     1904        Cycling    Cycling Track
#   844   St Louis     1904        Cycling    Cycling Track
#   845   St Louis     1904        Cycling    Cycling Track
#   846   St Louis     1904        Cycling    Cycling Track
#   847   St Louis     1904        Cycling    Cycling Track
#   848   St Louis     1904        Cycling    Cycling Track
#   849   St Louis     1904        Cycling    Cycling Track
#   850   St Louis     1904        Cycling    Cycling Track
#   851   St Louis     1904        Cycling    Cycling Track
#   852   St Louis     1904        Cycling    Cycling Track
#   853   St Louis     1904        Cycling    Cycling Track
#   854   St Louis     1904        Cycling    Cycling Track
#   855   St Louis     1904        Cycling    Cycling Track
#   856   St Louis     1904        Cycling    Cycling Track
#   857   St Louis     1904        Cycling    Cycling Track
#   858   St Louis     1904        Fencing          Fencing
#   859   St Louis     1904        Fencing          Fencing
#   860   St Louis     1904        Fencing          Fencing
#   861   St Louis     1904        Fencing          Fencing
#   862   St Louis     1904        Fencing          Fencing
#   863   St Louis     1904        Fencing          Fencing
#   864   St Louis     1904        Fencing          Fencing
#   865   St Louis     1904        Fencing          Fencing
#   866   St Louis     1904        Fencing          Fencing
#   867   St Louis     1904        Fencing          Fencing
#   868   St Louis     1904        Fencing          Fencing
#   869   St Louis     1904        Fencing          Fencing
#   870   St Louis     1904        Fencing          Fencing
#   871   St Louis     1904        Fencing          Fencing
#   872   St Louis     1904        Fencing          Fencing
#   873   St Louis     1904        Fencing          Fencing
#   874   St Louis     1904        Fencing          Fencing
#   875   St Louis     1904        Fencing          Fencing
#   876   St Louis     1904       Football         Football
#   877   St Louis     1904       Football         Football
#   878   St Louis     1904       Football         Football
#   879   St Louis     1904       Football         Football
#   880   St Louis     1904       Football         Football
#   881   St Louis     1904       Football         Football
#   882   St Louis     1904       Football         Football
#   883   St Louis     1904       Football         Football
#   884   St Louis     1904       Football         Football
#   885   St Louis     1904       Football         Football
#   886   St Louis     1904       Football         Football
#   887   St Louis     1904       Football         Football
#   888   St Louis     1904       Football         Football
#   889   St Louis     1904       Football         Football
#   890   St Louis     1904       Football         Football
#   891   St Louis     1904       Football         Football
#   892   St Louis     1904       Football         Football
#   893   St Louis     1904       Football         Football
#   894   St Louis     1904       Football         Football
#   895   St Louis     1904       Football         Football
#   896   St Louis     1904       Football         Football
#   897   St Louis     1904       Football         Football
#   898   St Louis     1904       Football         Football
#   899   St Louis     1904       Football         Football
#   900   St Louis     1904       Football         Football
#   901   St Louis     1904       Football         Football
#   902   St Louis     1904       Football         Football
#   903   St Louis     1904       Football         Football
#   904   St Louis     1904       Football         Football
#   905   St Louis     1904       Football         Football
#   906   St Louis     1904       Football         Football
#   907   St Louis     1904       Football         Football
#   908   St Louis     1904       Football         Football
#   909   St Louis     1904       Football         Football
#   910   St Louis     1904       Football         Football
#   911   St Louis     1904       Football         Football
#   912   St Louis     1904       Football         Football
#   913   St Louis     1904       Football         Football
#   914   St Louis     1904       Football         Football
#   915   St Louis     1904       Football         Football
#   916   St Louis     1904       Football         Football
#   917   St Louis     1904       Football         Football
#   918   St Louis     1904       Football         Football
#   919   St Louis     1904       Football         Football
#   920   St Louis     1904       Football         Football
#   921   St Louis     1904       Football         Football
#   922   St Louis     1904       Football         Football
#   923   St Louis     1904       Football         Football
#   924   St Louis     1904       Football         Football
#   925   St Louis     1904       Football         Football
#   926   St Louis     1904       Football         Football
#   927   St Louis     1904       Football         Football
#   928   St Louis     1904       Football         Football
#   929   St Louis     1904       Football         Football
#   930   St Louis     1904       Football         Football
#   931   St Louis     1904       Football         Football
#   932   St Louis     1904       Football         Football
#   933   St Louis     1904           Golf             Golf
#   934   St Louis     1904           Golf             Golf
#   935   St Louis     1904           Golf             Golf
#   936   St Louis     1904           Golf             Golf
#   937   St Louis     1904           Golf             Golf
#   938   St Louis     1904           Golf             Golf
#   939   St Louis     1904           Golf             Golf
#   940   St Louis     1904           Golf             Golf
#   941   St Louis     1904           Golf             Golf
#   942   St Louis     1904           Golf             Golf
#   943   St Louis     1904           Golf             Golf
#   944   St Louis     1904           Golf             Golf
#   945   St Louis     1904           Golf             Golf
#   946   St Louis     1904           Golf             Golf
#   947   St Louis     1904           Golf             Golf
#   948   St Louis     1904           Golf             Golf
#   949   St Louis     1904           Golf             Golf
#   950   St Louis     1904           Golf             Golf
#   951   St Louis     1904           Golf             Golf
#   952   St Louis     1904           Golf             Golf
#   953   St Louis     1904           Golf             Golf
#   954   St Louis     1904           Golf             Golf
#   955   St Louis     1904           Golf             Golf
#   956   St Louis     1904           Golf             Golf
#   957   St Louis     1904     Gymnastics      Artistic G.
#   958   St Louis     1904     Gymnastics      Artistic G.
#   959   St Louis     1904     Gymnastics      Artistic G.
#   960   St Louis     1904     Gymnastics      Artistic G.
#   961   St Louis     1904     Gymnastics      Artistic G.
#   962   St Louis     1904     Gymnastics      Artistic G.
#   963   St Louis     1904     Gymnastics      Artistic G.
#   964   St Louis     1904     Gymnastics      Artistic G.
#   965   St Louis     1904     Gymnastics      Artistic G.
#   966   St Louis     1904     Gymnastics      Artistic G.
#   967   St Louis     1904     Gymnastics      Artistic G.
#   968   St Louis     1904     Gymnastics      Artistic G.
#   969   St Louis     1904     Gymnastics      Artistic G.
#   970   St Louis     1904     Gymnastics      Artistic G.
#   971   St Louis     1904     Gymnastics      Artistic G.
#   972   St Louis     1904     Gymnastics      Artistic G.
#   973   St Louis     1904     Gymnastics      Artistic G.
#   974   St Louis     1904     Gymnastics      Artistic G.
#   975   St Louis     1904     Gymnastics      Artistic G.
#   976   St Louis     1904     Gymnastics      Artistic G.
# ...
#
#          NOC Gender                          Event Event_gender   Medal
#   13900  URS    Men                   10m platform            M  Bronze
#   13901  ITA    Men                   10m platform            M    Gold
#   13902  USA    Men                   10m platform            M  Silver
#   13903  USA  Women                   10m platform            W  Bronze
#   13904  URS  Women                   10m platform            W    Gold
#   ...    ...    ...                            ...          ...     ...
#   15200  URS    Men  82 - 90kg (light-heavyweight)            M    Gold
#   15201  BUL    Men  82 - 90kg (light-heavyweight)            M  Silver
#   15202  POL    Men       90 - 100kg (heavyweight)            M  Bronze
#   15203  URS    Men       90 - 100kg (heavyweight)            M    Gold
#   15204  BUL    Men       90 - 100kg (heavyweight)            M  Silver
#
#   [1305 rows x 10 columns]),
#  (1980,
#            City  Edition      Sport       Discipline              Athlete  NOC  \
#   15205  Moscow     1980   Aquatics           Diving  AMBARTSUMYAN, David  URS
#   15206  Moscow     1980   Aquatics           Diving       HOFFMANN, Falk  GDR
#   15207  Moscow     1980   Aquatics           Diving    ALEINIK, Vladimir  URS
#   15208  Moscow     1980   Aquatics           Diving      TSOTADZE, Liana  URS
#   15209  Moscow     1980   Aquatics           Diving     JÄSCHKE, Martina  GDR
#   ...       ...      ...        ...              ...                  ...  ...
#   16587  Moscow     1980  Wrestling  Wrestling Gre-R      NOTTNY, Norbert  HUN
#   16588  Moscow     1980  Wrestling  Wrestling Gre-R        KANYGIN, Igor  URS
#   16589  Moscow     1980  Wrestling  Wrestling Gre-R       ANDREI, Vasile  ROU
#   16590  Moscow     1980  Wrestling  Wrestling Gre-R       RAIKOV, Georgi  BUL
#   16591  Moscow     1980  Wrestling  Wrestling Gre-R        BIERLA, Roman  POL
#
#         Gender                          Event Event_gender   Medal
#   15205    Men                   10m platform            M  Bronze
#   15206    Men                   10m platform            M    Gold
#   15207    Men                   10m platform            M  Silver
#   15208  Women                   10m platform            W  Bronze
#   15209  Women                   10m platform            W    Gold
#   ...      ...                            ...          ...     ...
#   16587    Men  82 - 90kg (light-heavyweight)            M    Gold
#   16588    Men  82 - 90kg (light-heavyweight)            M  Silver
#   16589    Men       90 - 100kg (heavyweight)            M  Bronze
#   16590    Men       90 - 100kg (heavyweight)            M    Gold
#   16591    Men       90 - 100kg (heavyweight)            M  Silver
#
#   [1387 rows x 10 columns]),
#  (1984,
#                 City  Edition      Sport       Discipline  \
#   16592  Los Angeles     1984   Aquatics           Diving
#   16593  Los Angeles     1984   Aquatics           Diving
#   16594  Los Angeles     1984   Aquatics           Diving
#   16595  Los Angeles     1984   Aquatics           Diving
#   16596  Los Angeles     1984   Aquatics           Diving
#   ...            ...      ...        ...              ...
#   18046  Los Angeles     1984  Wrestling  Wrestling Gre-R
#   18047  Los Angeles     1984  Wrestling  Wrestling Gre-R
#   18048  Los Angeles     1984  Wrestling  Wrestling Gre-R
#   18049  Los Angeles     1984  Wrestling  Wrestling Gre-R
#   18050  Los Angeles     1984  Wrestling  Wrestling Gre-R
#
#                              Athlete  NOC Gender                          Event  \
#   16592               LI, Kong-Zheng  CHN    Men                   10m platform
#   16593            LOUGANIS, Gregory  USA    Men                   10m platform
#   16594            KIMBALL, Bruce D.  USA    Men                   10m platform
#   16595  WYLAND-WILLIAMS, Wendy Lian  USA  Women                   10m platform
#   16596                ZHOU, Ji-Hong  CHN  Women                   10m platform
#   ...                            ...  ...    ...                            ...
#   18046        FRASER, Steven Howard  USA    Men  82 - 90kg (light-heavyweight)
#   18047                  MATEI, Ilie  ROU    Men  82 - 90kg (light-heavyweight)
#   18048             TERTELIJE, Jozef  YUG    Men       90 - 100kg (heavyweight)
#   18049               ANDREI, Vasile  ROU    Men       90 - 100kg (heavyweight)
#   18050           GIBSON, Gregory P.  USA    Men       90 - 100kg (heavyweight)
#
#         Event_gender   Medal
#   16592            M  Bronze
#   16593            M    Gold
#   16594            M  Silver
#   16595            W  Bronze
#   16596            W    Gold
#   ...            ...     ...
#   18046            M    Gold
#   18047            M  Silver
#   18048            M  Bronze
#   18049            M    Gold
#   18050            M  Silver
#
#   [1459 rows x 10 columns]),
#  (1988,
#           City  Edition      Sport       Discipline  \
#   18051  Seoul     1988   Aquatics           Diving
#   18052  Seoul     1988   Aquatics           Diving
#   18053  Seoul     1988   Aquatics           Diving
#   18054  Seoul     1988   Aquatics           Diving
#   18055  Seoul     1988   Aquatics           Diving
#   ...      ...      ...        ...              ...
#   19592  Seoul     1988  Wrestling  Wrestling Gre-R
#   19593  Seoul     1988  Wrestling  Wrestling Gre-R
#   19594  Seoul     1988  Wrestling  Wrestling Gre-R
#   19595  Seoul     1988  Wrestling  Wrestling Gre-R
#   19596  Seoul     1988  Wrestling  Wrestling Gre-R
#
#                              Athlete  NOC Gender                          Event  \
#   18051           MENA CAMPOS, Jesus  MEX    Men                   10m platform
#   18052            LOUGANIS, Gregory  USA    Men                   10m platform
#   18053                    XIONG, Ni  CHN    Men                   10m platform
#   18054  WYLAND-WILLIAMS, Wendy Lian  USA  Women                   10m platform
#   18055                  XU, Yan-Mei  CHN  Women                   10m platform
#   ...                            ...  ...    ...                            ...
#   19592       KOMCHEV, Atanas Slavov  BUL    Men  82 - 90kg (light-heavyweight)
#   19593        KOSKELA, Harri Matias  FIN    Men  82 - 90kg (light-heavyweight)
#   19594     KOSLOWSKI, Dennis Marvin  USA    Men       90 - 100kg (heavyweight)
#   19595             WRONSKI, Andrzej  POL    Men       90 - 100kg (heavyweight)
#   19596              HIMMEL, Gerhard  FRG    Men       90 - 100kg (heavyweight)
#
#         Event_gender   Medal
#   18051            M  Bronze
#   18052            M    Gold
#   18053            M  Silver
#   18054            W  Bronze
#   18055            W    Gold
#   ...            ...     ...
#   19592            M    Gold
#   19593            M  Silver
#   19594            M  Bronze
#   19595            M    Gold
#   19596            M  Silver
#
#   [1546 rows x 10 columns]),
#  (1992,
#               City  Edition      Sport       Discipline  \
#   19597  Barcelona     1992   Aquatics           Diving
#   19598  Barcelona     1992   Aquatics           Diving
#   19599  Barcelona     1992   Aquatics           Diving
#   19600  Barcelona     1992   Aquatics           Diving
#   19601  Barcelona     1992   Aquatics           Diving
#   ...          ...      ...        ...              ...
#   21297  Barcelona     1992  Wrestling  Wrestling Gre-R
#   21298  Barcelona     1992  Wrestling  Wrestling Gre-R
#   21299  Barcelona     1992  Wrestling  Wrestling Gre-R
#   21300  Barcelona     1992  Wrestling  Wrestling Gre-R
#   21301  Barcelona     1992  Wrestling  Wrestling Gre-R
#
#                           Athlete  NOC Gender                          Event  \
#   19597                 XIONG, Ni  CHN    Men                   10m platform
#   19598               SUN, Shuwei  CHN    Men                   10m platform
#   19599           DONIE, Scott R.  USA    Men                   10m platform
#   19600         CLARK, Mary Ellen  USA  Women                   10m platform
#   19601               FU, Mingxia  CHN  Women                   10m platform
#   ...                         ...  ...    ...                            ...
#   21297            BULLMANN, Maik  GER    Men  82 - 90kg (light-heavyweight)
#   21298              BASAR, Hakki  TUR    Men  82 - 90kg (light-heavyweight)
#   21299  DEMIACHKIEVITCH, Serguei  EUN    Men       90 - 100kg (heavyweight)
#   21300      MILIAN PEREZ, Hector  CUB    Men       90 - 100kg (heavyweight)
#   21301  KOSLOWSKI, Dennis Marvin  USA    Men       90 - 100kg (heavyweight)
#
#         Event_gender   Medal
#   19597            M  Bronze
#   19598            M    Gold
#   19599            M  Silver
#   19600            W  Bronze
#   19601            W    Gold
#   ...            ...     ...
#   21297            M    Gold
#   21298            M  Silver
#   21299            M  Bronze
#   21300            M    Gold
#   21301            M  Silver
#
#   [1705 rows x 10 columns]),
#  (1996,
#             City  Edition      Sport       Discipline              Athlete  NOC  \
#   21302  Atlanta     1996   Aquatics           Diving       XIAO, Hailiang  CHN
#   21303  Atlanta     1996   Aquatics           Diving       SAUTIN, Dmitry  RUS
#   21304  Atlanta     1996   Aquatics           Diving          HEMPEL, Jan  GER
#   21305  Atlanta     1996   Aquatics           Diving    CLARK, Mary Ellen  USA
#   21306  Atlanta     1996   Aquatics           Diving          FU, Mingxia  CHN
#   ...        ...      ...        ...              ...                  ...  ...
#   23156  Atlanta     1996  Wrestling  Wrestling Gre-R  OLEYNYK, Vyacheslav  UKR
#   23157  Atlanta     1996  Wrestling  Wrestling Gre-R      FAFINSKI, Jacek  POL
#   23158  Atlanta     1996  Wrestling  Wrestling Gre-R    LJUNGBERG, Mikael  SWE
#   23159  Atlanta     1996  Wrestling  Wrestling Gre-R     WRONSKI, Andrzej  POL
#   23160  Atlanta     1996  Wrestling  Wrestling Gre-R     LISHTVAN, Sergey  BLR
#
#         Gender                          Event Event_gender   Medal
#   21302    Men                   10m platform            M  Bronze
#   21303    Men                   10m platform            M    Gold
#   21304    Men                   10m platform            M  Silver
#   21305  Women                   10m platform            W  Bronze
#   21306  Women                   10m platform            W    Gold
#   ...      ...                            ...          ...     ...
#   23156    Men  82 - 90kg (light-heavyweight)            M    Gold
#   23157    Men  82 - 90kg (light-heavyweight)            M  Silver
#   23158    Men       90 - 100kg (heavyweight)            M  Bronze
#   23159    Men       90 - 100kg (heavyweight)            M    Gold
#   23160    Men       90 - 100kg (heavyweight)            M  Silver
#
#   [1859 rows x 10 columns]),
#  (2000,
#            City  Edition      Sport       Discipline                   Athlete  \
#   23161  Sydney     2000   Aquatics           Diving            SAUTIN, Dmitry
#   23162  Sydney     2000   Aquatics           Diving               TIAN, Liang
#   23163  Sydney     2000   Aquatics           Diving                   HU, Jia
#   23164  Sydney     2000   Aquatics           Diving  MONTMINY, Anne Katherine
#   23165  Sydney     2000   Aquatics           Diving          WILKINSON, Laura
#   ...       ...      ...        ...              ...                       ...
#   25171  Sydney     2000  Wrestling  Wrestling Gre-R         LJUNGBERG, Mikael
#   25172  Sydney     2000  Wrestling  Wrestling Gre-R           SALDADZE, Davyd
#   25173  Sydney     2000  Wrestling  Wrestling Gre-R           DEBELKA, Dmitry
#   25174  Sydney     2000  Wrestling  Wrestling Gre-R            GARDNER, Rulon
#   25175  Sydney     2000  Wrestling  Wrestling Gre-R        KARELIN, Aleksandr
#
#          NOC Gender         Event Event_gender   Medal
#   23161  RUS    Men  10m platform            M  Bronze
#   23162  CHN    Men  10m platform            M    Gold
#   23163  CHN    Men  10m platform            M  Silver
#   23164  CAN  Women  10m platform            W  Bronze
#   23165  USA  Women  10m platform            W    Gold
#   ...    ...    ...           ...          ...     ...
#   25171  SWE    Men     85 - 97kg            M    Gold
#   25172  UKR    Men     85 - 97kg            M  Silver
#   25173  BLR    Men    97 - 130kg            M  Bronze
#   25174  USA    Men    97 - 130kg            M    Gold
#   25175  RUS    Men    97 - 130kg            M  Silver
#
#   [2015 rows x 10 columns]),
#  (2004,
#            City  Edition      Sport       Discipline               Athlete  NOC  \
#   25176  Athens     2004   Aquatics           Diving           TIAN, Liang  CHN
#   25177  Athens     2004   Aquatics           Diving               HU, Jia  CHN
#   25178  Athens     2004   Aquatics           Diving          HELM, Mathew  AUS
#   25179  Athens     2004   Aquatics           Diving         TOURKY, Loudy  AUS
#   25180  Athens     2004   Aquatics           Diving    NEWBERY, Chantelle  AUS
#   ...       ...      ...        ...              ...                   ...  ...
#   27169  Athens     2004  Wrestling  Wrestling Gre-R  GABER IBRAHIM, Karam  EGY
#   27170  Athens     2004  Wrestling  Wrestling Gre-R        NOZADZE, Ramaz  GEO
#   27171  Athens     2004  Wrestling  Wrestling Gre-R        GARDNER, Rulon  USA
#   27172  Athens     2004  Wrestling  Wrestling Gre-R        BAROEV, Khasan  RUS
#   27173  Athens     2004  Wrestling  Wrestling Gre-R   TSURTSUMIA, Georgiy  KAZ
#
#         Gender         Event Event_gender   Medal
#   25176    Men  10m platform            M  Bronze
#   25177    Men  10m platform            M    Gold
#   25178    Men  10m platform            M  Silver
#   25179  Women  10m platform            W  Bronze
#   25180  Women  10m platform            W    Gold
#   ...      ...           ...          ...     ...
#   27169    Men     84 - 96kg            M    Gold
#   27170    Men     84 - 96kg            M  Silver
#   27171    Men    96 - 120kg            M  Bronze
#   27172    Men    96 - 120kg            M    Gold
#   27173    Men    96 - 120kg            M  Silver
#
#   [1998 rows x 10 columns]),
#  (2008,
#             City  Edition      Sport       Discipline               Athlete  \
#   27174  Beijing     2008   Aquatics           Diving        GALPERIN, Gleb
#   27175  Beijing     2008   Aquatics           Diving      MITCHAM, Matthew
#   27176  Beijing     2008   Aquatics           Diving           ZHOU, Luxin
#   27177  Beijing     2008   Aquatics           Diving             WANG, Xin
#   27178  Beijing     2008   Aquatics           Diving          CHEN, Ruolin
#   ...        ...      ...        ...              ...                   ...
#   29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
#   29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
#   29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
#   29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
#   29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#          NOC Gender         Event Event_gender   Medal
#   27174  RUS    Men  10m platform            M  Bronze
#   27175  AUS    Men  10m platform            M    Gold
#   27176  CHN    Men  10m platform            M  Silver
#   27177  CHN  Women  10m platform            W  Bronze
#   27178  CHN  Women  10m platform            W    Gold
#   ...    ...    ...           ...          ...     ...
#   29211  GER    Men     84 - 96kg            M  Silver
#   29212  LTU    Men    96 - 120kg            M  Bronze
#   29213  ARM    Men    96 - 120kg            M  Bronze
#   29214  CUB    Men    96 - 120kg            M    Gold
#   29215  RUS    Men    96 - 120kg            M  Silver
#
#   [2042 rows x 10 columns])]

# %%
for group_key, group_val in oo.groupby('Edition'):
    print(group_key)
    print(group_val)
# Out:
# 1896
#        City  Edition          Sport       Discipline  \
# 0    Athens     1896       Aquatics         Swimming
# 1    Athens     1896       Aquatics         Swimming
# 2    Athens     1896       Aquatics         Swimming
# 3    Athens     1896       Aquatics         Swimming
# 4    Athens     1896       Aquatics         Swimming
# 5    Athens     1896       Aquatics         Swimming
# 6    Athens     1896       Aquatics         Swimming
# 7    Athens     1896       Aquatics         Swimming
# 8    Athens     1896       Aquatics         Swimming
# 9    Athens     1896       Aquatics         Swimming
# 10   Athens     1896       Aquatics         Swimming
# 11   Athens     1896      Athletics        Athletics
# 12   Athens     1896      Athletics        Athletics
# 13   Athens     1896      Athletics        Athletics
# 14   Athens     1896      Athletics        Athletics
# 15   Athens     1896      Athletics        Athletics
# 16   Athens     1896      Athletics        Athletics
# 17   Athens     1896      Athletics        Athletics
# 18   Athens     1896      Athletics        Athletics
# 19   Athens     1896      Athletics        Athletics
# 20   Athens     1896      Athletics        Athletics
# 21   Athens     1896      Athletics        Athletics
# 22   Athens     1896      Athletics        Athletics
# 23   Athens     1896      Athletics        Athletics
# 24   Athens     1896      Athletics        Athletics
# 25   Athens     1896      Athletics        Athletics
# 26   Athens     1896      Athletics        Athletics
# 27   Athens     1896      Athletics        Athletics
# 28   Athens     1896      Athletics        Athletics
# 29   Athens     1896      Athletics        Athletics
# 30   Athens     1896      Athletics        Athletics
# 31   Athens     1896      Athletics        Athletics
# 32   Athens     1896      Athletics        Athletics
# 33   Athens     1896      Athletics        Athletics
# 34   Athens     1896      Athletics        Athletics
# 35   Athens     1896      Athletics        Athletics
# 36   Athens     1896      Athletics        Athletics
# 37   Athens     1896      Athletics        Athletics
# 38   Athens     1896      Athletics        Athletics
# 39   Athens     1896      Athletics        Athletics
# 40   Athens     1896      Athletics        Athletics
# 41   Athens     1896      Athletics        Athletics
# 42   Athens     1896      Athletics        Athletics
# 43   Athens     1896      Athletics        Athletics
# 44   Athens     1896      Athletics        Athletics
# 45   Athens     1896      Athletics        Athletics
# 46   Athens     1896      Athletics        Athletics
# 47   Athens     1896      Athletics        Athletics
# 48   Athens     1896        Cycling     Cycling Road
# 49   Athens     1896        Cycling     Cycling Road
# 50   Athens     1896        Cycling     Cycling Road
# 51   Athens     1896        Cycling    Cycling Track
# 52   Athens     1896        Cycling    Cycling Track
# 53   Athens     1896        Cycling    Cycling Track
# 54   Athens     1896        Cycling    Cycling Track
# 55   Athens     1896        Cycling    Cycling Track
# 56   Athens     1896        Cycling    Cycling Track
# 57   Athens     1896        Cycling    Cycling Track
# 58   Athens     1896        Cycling    Cycling Track
# 59   Athens     1896        Cycling    Cycling Track
# 60   Athens     1896        Cycling    Cycling Track
# 61   Athens     1896        Cycling    Cycling Track
# 62   Athens     1896        Cycling    Cycling Track
# 63   Athens     1896        Cycling    Cycling Track
# 64   Athens     1896        Fencing          Fencing
# 65   Athens     1896        Fencing          Fencing
# 66   Athens     1896        Fencing          Fencing
# 67   Athens     1896        Fencing          Fencing
# 68   Athens     1896        Fencing          Fencing
# 69   Athens     1896        Fencing          Fencing
# 70   Athens     1896        Fencing          Fencing
# 71   Athens     1896        Fencing          Fencing
# 72   Athens     1896     Gymnastics      Artistic G.
# 73   Athens     1896     Gymnastics      Artistic G.
# 74   Athens     1896     Gymnastics      Artistic G.
# 75   Athens     1896     Gymnastics      Artistic G.
# 76   Athens     1896     Gymnastics      Artistic G.
# 77   Athens     1896     Gymnastics      Artistic G.
# 78   Athens     1896     Gymnastics      Artistic G.
# 79   Athens     1896     Gymnastics      Artistic G.
# 80   Athens     1896     Gymnastics      Artistic G.
# 81   Athens     1896     Gymnastics      Artistic G.
# 82   Athens     1896     Gymnastics      Artistic G.
# 83   Athens     1896     Gymnastics      Artistic G.
# 84   Athens     1896     Gymnastics      Artistic G.
# 85   Athens     1896     Gymnastics      Artistic G.
# 86   Athens     1896     Gymnastics      Artistic G.
# 87   Athens     1896     Gymnastics      Artistic G.
# 88   Athens     1896     Gymnastics      Artistic G.
# 89   Athens     1896     Gymnastics      Artistic G.
# 90   Athens     1896     Gymnastics      Artistic G.
# 91   Athens     1896     Gymnastics      Artistic G.
# 92   Athens     1896     Gymnastics      Artistic G.
# 93   Athens     1896     Gymnastics      Artistic G.
# 94   Athens     1896     Gymnastics      Artistic G.
# 95   Athens     1896     Gymnastics      Artistic G.
# 96   Athens     1896     Gymnastics      Artistic G.
# 97   Athens     1896     Gymnastics      Artistic G.
# 98   Athens     1896     Gymnastics      Artistic G.
# 99   Athens     1896     Gymnastics      Artistic G.
# 100  Athens     1896     Gymnastics      Artistic G.
# 101  Athens     1896     Gymnastics      Artistic G.
# 102  Athens     1896     Gymnastics      Artistic G.
# 103  Athens     1896     Gymnastics      Artistic G.
# 104  Athens     1896     Gymnastics      Artistic G.
# 105  Athens     1896     Gymnastics      Artistic G.
# 106  Athens     1896     Gymnastics      Artistic G.
# 107  Athens     1896     Gymnastics      Artistic G.
# 108  Athens     1896     Gymnastics      Artistic G.
# 109  Athens     1896     Gymnastics      Artistic G.
# 110  Athens     1896     Gymnastics      Artistic G.
# 111  Athens     1896     Gymnastics      Artistic G.
# 112  Athens     1896     Gymnastics      Artistic G.
# 113  Athens     1896     Gymnastics      Artistic G.
# 114  Athens     1896     Gymnastics      Artistic G.
# 115  Athens     1896     Gymnastics      Artistic G.
# 116  Athens     1896     Gymnastics      Artistic G.
# 117  Athens     1896       Shooting         Shooting
# 118  Athens     1896       Shooting         Shooting
# 119  Athens     1896       Shooting         Shooting
# 120  Athens     1896       Shooting         Shooting
# 121  Athens     1896       Shooting         Shooting
# 122  Athens     1896       Shooting         Shooting
# 123  Athens     1896       Shooting         Shooting
# 124  Athens     1896       Shooting         Shooting
# 125  Athens     1896       Shooting         Shooting
# 126  Athens     1896       Shooting         Shooting
# 127  Athens     1896       Shooting         Shooting
# 128  Athens     1896       Shooting         Shooting
# 129  Athens     1896       Shooting         Shooting
# 130  Athens     1896       Shooting         Shooting
# 131  Athens     1896       Shooting         Shooting
# 132  Athens     1896         Tennis           Tennis
# 133  Athens     1896         Tennis           Tennis
# 134  Athens     1896         Tennis           Tennis
# 135  Athens     1896         Tennis           Tennis
# 136  Athens     1896         Tennis           Tennis
# 137  Athens     1896         Tennis           Tennis
# 138  Athens     1896         Tennis           Tennis
# 139  Athens     1896         Tennis           Tennis
# 140  Athens     1896         Tennis           Tennis
# 141  Athens     1896         Tennis           Tennis
# 142  Athens     1896  Weightlifting    Weightlifting
# 143  Athens     1896  Weightlifting    Weightlifting
# 144  Athens     1896  Weightlifting    Weightlifting
# 145  Athens     1896  Weightlifting    Weightlifting
# 146  Athens     1896  Weightlifting    Weightlifting
# 147  Athens     1896  Weightlifting    Weightlifting
# 148  Athens     1896      Wrestling  Wrestling Gre-R
# 149  Athens     1896      Wrestling  Wrestling Gre-R
# 150  Athens     1896      Wrestling  Wrestling Gre-R
#
#                                Athlete  NOC Gender  \
# 0                        HAJOS, Alfred  HUN    Men
# 1                     HERSCHMANN, Otto  AUT    Men
# 2                    DRIVAS, Dimitrios  GRE    Men
# 3                   MALOKINIS, Ioannis  GRE    Men
# 4                   CHASAPIS, Spiridon  GRE    Men
# 5                CHOROPHAS, Efstathios  GRE    Men
# 6                        HAJOS, Alfred  HUN    Men
# 7                     ANDREOU, Joannis  GRE    Men
# 8                CHOROPHAS, Efstathios  GRE    Men
# 9                        NEUMANN, Paul  AUT    Men
# 10                   PEPANOS, Antonios  GRE    Men
# 11                       LANE, Francis  USA    Men
# 12                    SZOKOLYI, Alajos  HUN    Men
# 13                       BURKE, Thomas  USA    Men
# 14                      HOFMANN, Fritz  GER    Men
# 15                      CURTIS, Thomas  USA    Men
# 16                  GOULDING, Grantley  GBR    Men
# 17                   LERMUSIAUX, Albin  FRA    Men
# 18                        FLACK, Edwin  AUS    Men
# 19                       BLAKE, Arthur  USA    Men
# 20                     GMELIN, Charles  GBR    Men
# 21                       BURKE, Thomas  USA    Men
# 22                    JAMISON, Herbert  USA    Men
# 23                  GOLEMIS, Dimitrios  GRE    Men
# 24                        FLACK, Edwin  AUS    Men
# 25                        DANI, Nandor  HUN    Men
# 26                    VERSIS, Sotirios  GRE    Men
# 27                     GARRETT, Robert  USA    Men
# 28         PARASKEVOPOULOS, Panagiotis  GRE    Men
# 29                       CLARK, Ellery  USA    Men
# 30                     CONNOLLY, James  USA    Men
# 31                     GARRETT, Robert  USA    Men
# 32                     CONNOLLY, James  USA    Men
# 33                       CLARK, Ellery  USA    Men
# 34                     GARRETT, Robert  USA    Men
# 35                      KELLNER, Gyula  HUN    Men
# 36                     LOUIS, Spyridon  GRE    Men
# 37                VASILAKOS, Kharilaos  GRE    Men
# 38                 DAMASKOS, Evangelos  GRE    Men
# 39             THEODOROPOULOS, Ioannis  GRE    Men
# 40                HOYT, William Welles  USA    Men
# 41                       TYLER, Albert  USA    Men
# 42               PAPASIDERIS, Georgios  GRE    Men
# 43                     GARRETT, Robert  USA    Men
# 44                  GOUSKOS, Miltiadis  GRE    Men
# 45                   PERSAKIS, Ioannis  GRE    Men
# 46                     CONNOLLY, James  USA    Men
# 47                  TUFFERI, Alexandre  FRA    Men
# 48                      BATTEL, Edward  GBR    Men
# 49           KONSTANTINIDIS, Aristidis  GRE    Men
# 50                    GOEDRICH, August  GER    Men
# 51                       FLAMENG, Léon  FRA    Men
# 52                  KOLETTIS, Georgios  GRE    Men
# 53                       SCHMAL, Adolf  AUT    Men
# 54                        MASSON, Paul  FRA    Men
# 55                       FLAMENG, Léon  FRA    Men
# 56                       SCHMAL, Adolf  AUT    Men
# 57                      KEEPING, Frank  GBR    Men
# 58                       SCHMAL, Adolf  AUT    Men
# 59                        MASSON, Paul  FRA    Men
# 60             NIKOLOPOULOS, Stamatios  GRE    Men
# 61                       FLAMENG, Léon  FRA    Men
# 62                        MASSON, Paul  FRA    Men
# 63             NIKOLOPOULOS, Stamatios  GRE    Men
# 64   PIERRAKOS-MAVROMICHALIS, Perikles  GRE    Men
# 65            GRAVELOTTE, Eugène-Henri  FRA    Men
# 66                       CALLOT, Henri  FRA    Men
# 67                    PYRGOS, Leonidas  GRE    Men
# 68                  PERRONNET, Maurice  FRA    Men
# 69                     NIELSEN, Holger  DEN    Men
# 70                 GEORGIADIS, Ioannis  GRE    Men
# 71               KARAKALOS, Telemachos  GRE    Men
# 72                WEINGÄRTNER, Hermann  GER    Men
# 73                      FLATOW, Alfred  GER    Men
# 74                      FLATOW, Alfred  GER    Men
# 75                       ZUTTER, Louis  SUI    Men
# 76                       ZUTTER, Louis  SUI    Men
# 77                WEINGÄRTNER, Hermann  GER    Men
# 78                    PERSAKIS, Petros  GRE    Men
# 79                MITROPOULOS, Ioannis  GRE    Men
# 80                WEINGÄRTNER, Hermann  GER    Men
# 81                      HOFMANN, Fritz  GER    Men
# 82            ANDRIAKOPOULOS, Nicolaos  GRE    Men
# 83                  XENAKIS, Thomasios  GRE    Men
# 84                      BÖCKER, Konrad  GER    Men
# 85                      FLATOW, Alfred  GER    Men
# 86                FLATOW, Gustav Felix  GER    Men
# 87                       HILMAR, Georg  GER    Men
# 88                      HOFMANN, Fritz  GER    Men
# 89                   MANTEUFFEL, Fritz  GER    Men
# 90                      NEUKIRCH, Karl  GER    Men
# 91                     RÖSTEL, Richard  GER    Men
# 92                      SCHUFT, Gustav  GER    Men
# 93                      SCHUMANN, Carl  GER    Men
# 94                WEINGÄRTNER, Hermann  GER    Men
# 95                 CHRYSAPHIS, Ioannis  GRE    Men
# 96                KARVELAS, Phillippos  GRE    Men
# 97                 LOUNDRAS, Dimitrios  GRE    Men
# 98                MITROPOULOS, Ioannis  GRE    Men
# 99                      BÖCKER, Konrad  GER    Men
# 100                     FLATOW, Alfred  GER    Men
# 101               FLATOW, Gustav Felix  GER    Men
# 102                      HILMAR, Georg  GER    Men
# 103                     HOFMANN, Fritz  GER    Men
# 104                  MANTEUFFEL, Fritz  GER    Men
# 105                     NEUKIRCH, Karl  GER    Men
# 106                    RÖSTEL, Richard  GER    Men
# 107                     SCHUFT, Gustav  GER    Men
# 108                     SCHUMANN, Carl  GER    Men
# 109               WEINGÄRTNER, Hermann  GER    Men
# 110           ANDRIAKOPOULOS, Nicolaos  GRE    Men
# 111             ATHANASOPOULOS, Spyros  GRE    Men
# 112                   PERSAKIS, Petros  GRE    Men
# 113                 XENAKIS, Thomasios  GRE    Men
# 114               WEINGÄRTNER, Hermann  GER    Men
# 115                     SCHUMANN, Carl  GER    Men
# 116                      ZUTTER, Louis  SUI    Men
# 117                  MORAKIS, Nikolaos  GRE    Men
# 118                        PAINE, John  USA    Men
# 119                      PAINE, Sumner  USA    Men
# 120                    NIELSEN, Holger  DEN    Men
# 121               PHRANGOUDIS, Joannis  GRE    Men
# 122               ORPHANIDIS, Georgios  GRE    Men
# 123               PHRANGOUDIS, Joannis  GRE    Men
# 124                      PAINE, Sumner  USA    Men
# 125                    NIELSEN, Holger  DEN    Men
# 126                 TRIKUPIS, Nicolaos  GRE    Men
# 127               KARASEVDAS, Pantelis  GRE    Men
# 128                   PAVLIDIS, Pavlos  GRE    Men
# 129                      JENSEN, Viggo  DEN    Men
# 130               ORPHANIDIS, Georgios  GRE    Men
# 131               PHRANGOUDIS, Joannis  GRE    Men
# 132                       FLACK, Edwin  ZZX    Men
# 133           ROBERTSON, George Stuart  ZZX    Men
# 134                       BOLAND, John  ZZX    Men
# 135                   TRAUN, Friedrich  ZZX    Men
# 136               KASDAGLIS, Dionysios  ZZX    Men
# 137           PETROKOKKINOS, Demetrios  ZZX    Men
# 138             PASPATIS, Konstantinos  GRE    Men
# 139               TAPAVICZA, Momcsillo  HUN    Men
# 140                       BOLAND, John  GBR    Men
# 141               KASDAGLIS, Dionysios  GRE    Men
# 142           NIKOLOPOULOS, Alexandros  GRE    Men
# 143                ELLIOTT, Launceston  GBR    Men
# 144                      JENSEN, Viggo  DEN    Men
# 145                   VERSIS, Sotirios  GRE    Men
# 146                      JENSEN, Viggo  DEN    Men
# 147                ELLIOTT, Launceston  GBR    Men
# 148           CHRISTOPOULOS, Stephanos  GRE    Men
# 149                     SCHUMANN, Carl  GER    Men
# 150                   TSITAS, Georgios  GRE    Men
#
#                                 Event Event_gender   Medal
# 0                      100m freestyle            M    Gold
# 1                      100m freestyle            M  Silver
# 2          100m freestyle for sailors            M  Bronze
# 3          100m freestyle for sailors            M    Gold
# 4          100m freestyle for sailors            M  Silver
# 5                     1200m freestyle            M  Bronze
# 6                     1200m freestyle            M    Gold
# 7                     1200m freestyle            M  Silver
# 8                      400m freestyle            M  Bronze
# 9                      400m freestyle            M    Gold
# 10                     400m freestyle            M  Silver
# 11                               100m            M  Bronze
# 12                               100m            M  Bronze
# 13                               100m            M    Gold
# 14                               100m            M  Silver
# 15                       110m hurdles            M    Gold
# 16                       110m hurdles            M  Silver
# 17                              1500m            M  Bronze
# 18                              1500m            M    Gold
# 19                              1500m            M  Silver
# 20                               400m            M  Bronze
# 21                               400m            M    Gold
# 22                               400m            M  Silver
# 23                               800m            M  Bronze
# 24                               800m            M    Gold
# 25                               800m            M  Silver
# 26                       discus throw            M  Bronze
# 27                       discus throw            M    Gold
# 28                       discus throw            M  Silver
# 29                          high jump            M    Gold
# 30                          high jump            M  Silver
# 31                          high jump            M  Silver
# 32                          long jump            M  Bronze
# 33                          long jump            M    Gold
# 34                          long jump            M  Silver
# 35                           marathon            M  Bronze
# 36                           marathon            M    Gold
# 37                           marathon            M  Silver
# 38                         pole vault            M  Bronze
# 39                         pole vault            M  Bronze
# 40                         pole vault            M    Gold
# 41                         pole vault            M  Silver
# 42                           shot put            M  Bronze
# 43                           shot put            M    Gold
# 44                           shot put            M  Silver
# 45                        triple jump            M  Bronze
# 46                        triple jump            M    Gold
# 47                        triple jump            M  Silver
# 48               individual road race            M  Bronze
# 49               individual road race            M    Gold
# 50               individual road race            M  Silver
# 51                              100km            M    Gold
# 52                              100km            M  Silver
# 53                               10km            M  Bronze
# 54                               10km            M    Gold
# 55                               10km            M  Silver
# 56                       12-hour race            M    Gold
# 57                       12-hour race            M  Silver
# 58                     1km time trial            M  Bronze
# 59                     1km time trial            M    Gold
# 60                     1km time trial            M  Silver
# 61                    Sprint indivual            M  Bronze
# 62                    Sprint indivual            M    Gold
# 63                    Sprint indivual            M  Silver
# 64                    foil individual            M  Bronze
# 65                    foil individual            M    Gold
# 66                    foil individual            M  Silver
# 67                      foil, masters            M    Gold
# 68                      foil, masters            M  Silver
# 69                   sabre individual            M  Bronze
# 70                   sabre individual            M    Gold
# 71                   sabre individual            M  Silver
# 72                     horizontal bar            M    Gold
# 73                     horizontal bar            M  Silver
# 74                      parallel bars            M    Gold
# 75                      parallel bars            M  Silver
# 76                       pommel horse            M    Gold
# 77                       pommel horse            M  Silver
# 78                              rings            M  Bronze
# 79                              rings            M    Gold
# 80                              rings            M  Silver
# 81                      rope climbing            M  Bronze
# 82                      rope climbing            M    Gold
# 83                      rope climbing            M  Silver
# 84               team, horizontal bar            M    Gold
# 85               team, horizontal bar            M    Gold
# 86               team, horizontal bar            M    Gold
# 87               team, horizontal bar            M    Gold
# 88               team, horizontal bar            M    Gold
# 89               team, horizontal bar            M    Gold
# 90               team, horizontal bar            M    Gold
# 91               team, horizontal bar            M    Gold
# 92               team, horizontal bar            M    Gold
# 93               team, horizontal bar            M    Gold
# 94               team, horizontal bar            M    Gold
# 95                team, parallel bars            M  Bronze
# 96                team, parallel bars            M  Bronze
# 97                team, parallel bars            M  Bronze
# 98                team, parallel bars            M  Bronze
# 99                team, parallel bars            M    Gold
# 100               team, parallel bars            M    Gold
# 101               team, parallel bars            M    Gold
# 102               team, parallel bars            M    Gold
# 103               team, parallel bars            M    Gold
# 104               team, parallel bars            M    Gold
# 105               team, parallel bars            M    Gold
# 106               team, parallel bars            M    Gold
# 107               team, parallel bars            M    Gold
# 108               team, parallel bars            M    Gold
# 109               team, parallel bars            M    Gold
# 110               team, parallel bars            M  Silver
# 111               team, parallel bars            M  Silver
# 112               team, parallel bars            M  Silver
# 113               team, parallel bars            M  Silver
# 114                             vault            M  Bronze
# 115                             vault            M    Gold
# 116                             vault            M  Silver
# 117                   25m army pistol            M  Bronze
# 118                   25m army pistol            M    Gold
# 119                   25m army pistol            M  Silver
# 120  25m rapid fire pistol (60 shots)            M  Bronze
# 121  25m rapid fire pistol (60 shots)            M    Gold
# 122  25m rapid fire pistol (60 shots)            M  Silver
# 123             50m pistol (60 shots)            M  Bronze
# 124             50m pistol (60 shots)            M    Gold
# 125             50m pistol (60 shots)            M  Silver
# 126                  army rifle, 200m            M  Bronze
# 127                  army rifle, 200m            M    Gold
# 128                  army rifle, 200m            M  Silver
# 129                  army rifle, 300m            M  Bronze
# 130                  army rifle, 300m            M    Gold
# 131                  army rifle, 300m            M  Silver
# 132                           doubles            M  Bronze
# 133                           doubles            M  Bronze
# 134                           doubles            M    Gold
# 135                           doubles            M    Gold
# 136                           doubles            M  Silver
# 137                           doubles            M  Silver
# 138                           singles            M  Bronze
# 139                           singles            M  Bronze
# 140                           singles            M    Gold
# 141                           singles            M  Silver
# 142       heavyweight - one hand lift            M  Bronze
# 143       heavyweight - one hand lift            M    Gold
# 144       heavyweight - one hand lift            M  Silver
# 145       heavyweight - two hand lift            M  Bronze
# 146       heavyweight - two hand lift            M    Gold
# 147       heavyweight - two hand lift            M  Silver
# 148                        open event            M  Bronze
# 149                        open event            M    Gold
# 150                        open event            M  Silver
# 1900
#       City  Edition       Sport  Discipline  \
# 151  Paris     1900    Aquatics    Swimming
# 152  Paris     1900    Aquatics    Swimming
# 153  Paris     1900    Aquatics    Swimming
# 154  Paris     1900    Aquatics    Swimming
# 155  Paris     1900    Aquatics    Swimming
# ..     ...      ...         ...         ...
# 658  Paris     1900  Tug of War  Tug of War
# 659  Paris     1900  Tug of War  Tug of War
# 660  Paris     1900  Tug of War  Tug of War
# 661  Paris     1900  Tug of War  Tug of War
# 662  Paris     1900  Tug of War  Tug of War
#
#                                Athlete  NOC Gender            Event  \
# 151                     HALMAY, Zoltan  HUN    Men  1500m freestyle
# 152                JARVIS, John Arthur  GBR    Men  1500m freestyle
# 153                        WAHLE, Otto  AUT    Men  1500m freestyle
# 154                    DROST, Johannes  NED    Men  200m backstroke
# 155                  HOPPENBERG, Ernst  GER    Men  200m backstroke
# ..                                 ...  ...    ...              ...
# 658                       COLLAS, Jean  FRA    Men       tug of war
# 659                  GONDOUIN, Charles  FRA    Men       tug of war
# 660  HENRIQUEZ DE ZUBIERRA, Constantin  FRA    Men       tug of war
# 661                      ROFFO, Joseph  FRA    Men       tug of war
# 662                     SARRADE, Emile  FRA    Men       tug of war
#
#     Event_gender   Medal
# 151            M  Bronze
# 152            M    Gold
# 153            M  Silver
# 154            M  Bronze
# 155            M    Gold
# ..           ...     ...
# 658            M  Silver
# 659            M  Silver
# 660            M  Silver
# 661            M  Silver
# 662            M  Silver
#
# [512 rows x 10 columns]
# 1904
#           City  Edition          Sport       Discipline  \
# 663   St Louis     1904       Aquatics           Diving
# 664   St Louis     1904       Aquatics           Diving
# 665   St Louis     1904       Aquatics           Diving
# 666   St Louis     1904       Aquatics           Diving
# 667   St Louis     1904       Aquatics           Diving
# 668   St Louis     1904       Aquatics           Diving
# 669   St Louis     1904       Aquatics           Diving
# 670   St Louis     1904       Aquatics         Swimming
# 671   St Louis     1904       Aquatics         Swimming
# 672   St Louis     1904       Aquatics         Swimming
# 673   St Louis     1904       Aquatics         Swimming
# 674   St Louis     1904       Aquatics         Swimming
# 675   St Louis     1904       Aquatics         Swimming
# 676   St Louis     1904       Aquatics         Swimming
# 677   St Louis     1904       Aquatics         Swimming
# 678   St Louis     1904       Aquatics         Swimming
# 679   St Louis     1904       Aquatics         Swimming
# 680   St Louis     1904       Aquatics         Swimming
# 681   St Louis     1904       Aquatics         Swimming
# 682   St Louis     1904       Aquatics         Swimming
# 683   St Louis     1904       Aquatics         Swimming
# 684   St Louis     1904       Aquatics         Swimming
# 685   St Louis     1904       Aquatics         Swimming
# 686   St Louis     1904       Aquatics         Swimming
# 687   St Louis     1904       Aquatics         Swimming
# 688   St Louis     1904       Aquatics         Swimming
# 689   St Louis     1904       Aquatics         Swimming
# 690   St Louis     1904       Aquatics         Swimming
# 691   St Louis     1904       Aquatics         Swimming
# 692   St Louis     1904       Aquatics         Swimming
# 693   St Louis     1904       Aquatics         Swimming
# 694   St Louis     1904       Aquatics         Swimming
# 695   St Louis     1904       Aquatics         Swimming
# 696   St Louis     1904       Aquatics         Swimming
# 697   St Louis     1904       Aquatics         Swimming
# 698   St Louis     1904       Aquatics         Swimming
# 699   St Louis     1904       Aquatics         Swimming
# 700   St Louis     1904       Aquatics         Swimming
# 701   St Louis     1904       Aquatics         Swimming
# 702   St Louis     1904       Aquatics         Swimming
# 703   St Louis     1904       Aquatics         Swimming
# 704   St Louis     1904       Aquatics         Swimming
# 705   St Louis     1904       Aquatics         Swimming
# 706   St Louis     1904        Archery          Archery
# 707   St Louis     1904        Archery          Archery
# 708   St Louis     1904        Archery          Archery
# 709   St Louis     1904        Archery          Archery
# 710   St Louis     1904        Archery          Archery
# 711   St Louis     1904        Archery          Archery
# 712   St Louis     1904        Archery          Archery
# 713   St Louis     1904        Archery          Archery
# 714   St Louis     1904        Archery          Archery
# 715   St Louis     1904        Archery          Archery
# 716   St Louis     1904        Archery          Archery
# 717   St Louis     1904        Archery          Archery
# 718   St Louis     1904        Archery          Archery
# 719   St Louis     1904        Archery          Archery
# 720   St Louis     1904        Archery          Archery
# 721   St Louis     1904        Archery          Archery
# 722   St Louis     1904        Archery          Archery
# 723   St Louis     1904        Archery          Archery
# 724   St Louis     1904        Archery          Archery
# 725   St Louis     1904        Archery          Archery
# 726   St Louis     1904        Archery          Archery
# 727   St Louis     1904        Archery          Archery
# 728   St Louis     1904        Archery          Archery
# 729   St Louis     1904        Archery          Archery
# 730   St Louis     1904        Archery          Archery
# 731   St Louis     1904        Archery          Archery
# 732   St Louis     1904        Archery          Archery
# 733   St Louis     1904        Archery          Archery
# 734   St Louis     1904        Archery          Archery
# 735   St Louis     1904        Archery          Archery
# 736   St Louis     1904      Athletics        Athletics
# 737   St Louis     1904      Athletics        Athletics
# 738   St Louis     1904      Athletics        Athletics
# 739   St Louis     1904      Athletics        Athletics
# 740   St Louis     1904      Athletics        Athletics
# 741   St Louis     1904      Athletics        Athletics
# 742   St Louis     1904      Athletics        Athletics
# 743   St Louis     1904      Athletics        Athletics
# 744   St Louis     1904      Athletics        Athletics
# 745   St Louis     1904      Athletics        Athletics
# 746   St Louis     1904      Athletics        Athletics
# 747   St Louis     1904      Athletics        Athletics
# 748   St Louis     1904      Athletics        Athletics
# 749   St Louis     1904      Athletics        Athletics
# 750   St Louis     1904      Athletics        Athletics
# 751   St Louis     1904      Athletics        Athletics
# 752   St Louis     1904      Athletics        Athletics
# 753   St Louis     1904      Athletics        Athletics
# 754   St Louis     1904      Athletics        Athletics
# 755   St Louis     1904      Athletics        Athletics
# 756   St Louis     1904      Athletics        Athletics
# 757   St Louis     1904      Athletics        Athletics
# 758   St Louis     1904      Athletics        Athletics
# 759   St Louis     1904      Athletics        Athletics
# 760   St Louis     1904      Athletics        Athletics
# 761   St Louis     1904      Athletics        Athletics
# 762   St Louis     1904      Athletics        Athletics
# 763   St Louis     1904      Athletics        Athletics
# 764   St Louis     1904      Athletics        Athletics
# 765   St Louis     1904      Athletics        Athletics
# 766   St Louis     1904      Athletics        Athletics
# 767   St Louis     1904      Athletics        Athletics
# 768   St Louis     1904      Athletics        Athletics
# 769   St Louis     1904      Athletics        Athletics
# 770   St Louis     1904      Athletics        Athletics
# 771   St Louis     1904      Athletics        Athletics
# 772   St Louis     1904      Athletics        Athletics
# 773   St Louis     1904      Athletics        Athletics
# 774   St Louis     1904      Athletics        Athletics
# 775   St Louis     1904      Athletics        Athletics
# 776   St Louis     1904      Athletics        Athletics
# 777   St Louis     1904      Athletics        Athletics
# 778   St Louis     1904      Athletics        Athletics
# 779   St Louis     1904      Athletics        Athletics
# 780   St Louis     1904      Athletics        Athletics
# 781   St Louis     1904      Athletics        Athletics
# 782   St Louis     1904      Athletics        Athletics
# 783   St Louis     1904      Athletics        Athletics
# 784   St Louis     1904      Athletics        Athletics
# 785   St Louis     1904      Athletics        Athletics
# 786   St Louis     1904      Athletics        Athletics
# 787   St Louis     1904      Athletics        Athletics
# 788   St Louis     1904      Athletics        Athletics
# 789   St Louis     1904      Athletics        Athletics
# 790   St Louis     1904      Athletics        Athletics
# 791   St Louis     1904      Athletics        Athletics
# 792   St Louis     1904      Athletics        Athletics
# 793   St Louis     1904      Athletics        Athletics
# 794   St Louis     1904      Athletics        Athletics
# 795   St Louis     1904      Athletics        Athletics
# 796   St Louis     1904      Athletics        Athletics
# 797   St Louis     1904      Athletics        Athletics
# 798   St Louis     1904      Athletics        Athletics
# 799   St Louis     1904      Athletics        Athletics
# 800   St Louis     1904      Athletics        Athletics
# 801   St Louis     1904      Athletics        Athletics
# 802   St Louis     1904      Athletics        Athletics
# 803   St Louis     1904      Athletics        Athletics
# 804   St Louis     1904      Athletics        Athletics
# 805   St Louis     1904      Athletics        Athletics
# 806   St Louis     1904      Athletics        Athletics
# 807   St Louis     1904      Athletics        Athletics
# 808   St Louis     1904      Athletics        Athletics
# 809   St Louis     1904      Athletics        Athletics
# 810   St Louis     1904      Athletics        Athletics
# 811   St Louis     1904      Athletics        Athletics
# 812   St Louis     1904      Athletics        Athletics
# 813   St Louis     1904      Athletics        Athletics
# 814   St Louis     1904      Athletics        Athletics
# 815   St Louis     1904      Athletics        Athletics
# 816   St Louis     1904      Athletics        Athletics
# 817   St Louis     1904      Athletics        Athletics
# 818   St Louis     1904         Boxing           Boxing
# 819   St Louis     1904         Boxing           Boxing
# 820   St Louis     1904         Boxing           Boxing
# 821   St Louis     1904         Boxing           Boxing
# 822   St Louis     1904         Boxing           Boxing
# 823   St Louis     1904         Boxing           Boxing
# 824   St Louis     1904         Boxing           Boxing
# 825   St Louis     1904         Boxing           Boxing
# 826   St Louis     1904         Boxing           Boxing
# 827   St Louis     1904         Boxing           Boxing
# 828   St Louis     1904         Boxing           Boxing
# 829   St Louis     1904         Boxing           Boxing
# 830   St Louis     1904         Boxing           Boxing
# 831   St Louis     1904         Boxing           Boxing
# 832   St Louis     1904         Boxing           Boxing
# 833   St Louis     1904         Boxing           Boxing
# 834   St Louis     1904         Boxing           Boxing
# 835   St Louis     1904         Boxing           Boxing
# 836   St Louis     1904         Boxing           Boxing
# 837   St Louis     1904        Cycling    Cycling Track
# 838   St Louis     1904        Cycling    Cycling Track
# 839   St Louis     1904        Cycling    Cycling Track
# 840   St Louis     1904        Cycling    Cycling Track
# 841   St Louis     1904        Cycling    Cycling Track
# 842   St Louis     1904        Cycling    Cycling Track
# 843   St Louis     1904        Cycling    Cycling Track
# 844   St Louis     1904        Cycling    Cycling Track
# 845   St Louis     1904        Cycling    Cycling Track
# 846   St Louis     1904        Cycling    Cycling Track
# 847   St Louis     1904        Cycling    Cycling Track
# 848   St Louis     1904        Cycling    Cycling Track
# 849   St Louis     1904        Cycling    Cycling Track
# 850   St Louis     1904        Cycling    Cycling Track
# 851   St Louis     1904        Cycling    Cycling Track
# 852   St Louis     1904        Cycling    Cycling Track
# 853   St Louis     1904        Cycling    Cycling Track
# 854   St Louis     1904        Cycling    Cycling Track
# 855   St Louis     1904        Cycling    Cycling Track
# 856   St Louis     1904        Cycling    Cycling Track
# 857   St Louis     1904        Cycling    Cycling Track
# 858   St Louis     1904        Fencing          Fencing
# 859   St Louis     1904        Fencing          Fencing
# 860   St Louis     1904        Fencing          Fencing
# 861   St Louis     1904        Fencing          Fencing
# 862   St Louis     1904        Fencing          Fencing
# 863   St Louis     1904        Fencing          Fencing
# 864   St Louis     1904        Fencing          Fencing
# 865   St Louis     1904        Fencing          Fencing
# 866   St Louis     1904        Fencing          Fencing
# 867   St Louis     1904        Fencing          Fencing
# 868   St Louis     1904        Fencing          Fencing
# 869   St Louis     1904        Fencing          Fencing
# 870   St Louis     1904        Fencing          Fencing
# 871   St Louis     1904        Fencing          Fencing
# 872   St Louis     1904        Fencing          Fencing
# 873   St Louis     1904        Fencing          Fencing
# 874   St Louis     1904        Fencing          Fencing
# 875   St Louis     1904        Fencing          Fencing
# 876   St Louis     1904       Football         Football
# 877   St Louis     1904       Football         Football
# 878   St Louis     1904       Football         Football
# 879   St Louis     1904       Football         Football
# 880   St Louis     1904       Football         Football
# 881   St Louis     1904       Football         Football
# 882   St Louis     1904       Football         Football
# 883   St Louis     1904       Football         Football
# 884   St Louis     1904       Football         Football
# 885   St Louis     1904       Football         Football
# 886   St Louis     1904       Football         Football
# 887   St Louis     1904       Football         Football
# 888   St Louis     1904       Football         Football
# 889   St Louis     1904       Football         Football
# 890   St Louis     1904       Football         Football
# 891   St Louis     1904       Football         Football
# 892   St Louis     1904       Football         Football
# 893   St Louis     1904       Football         Football
# 894   St Louis     1904       Football         Football
# 895   St Louis     1904       Football         Football
# 896   St Louis     1904       Football         Football
# 897   St Louis     1904       Football         Football
# 898   St Louis     1904       Football         Football
# 899   St Louis     1904       Football         Football
# 900   St Louis     1904       Football         Football
# 901   St Louis     1904       Football         Football
# 902   St Louis     1904       Football         Football
# 903   St Louis     1904       Football         Football
# 904   St Louis     1904       Football         Football
# 905   St Louis     1904       Football         Football
# 906   St Louis     1904       Football         Football
# 907   St Louis     1904       Football         Football
# 908   St Louis     1904       Football         Football
# 909   St Louis     1904       Football         Football
# 910   St Louis     1904       Football         Football
# 911   St Louis     1904       Football         Football
# 912   St Louis     1904       Football         Football
# 913   St Louis     1904       Football         Football
# 914   St Louis     1904       Football         Football
# 915   St Louis     1904       Football         Football
# 916   St Louis     1904       Football         Football
# 917   St Louis     1904       Football         Football
# 918   St Louis     1904       Football         Football
# 919   St Louis     1904       Football         Football
# 920   St Louis     1904       Football         Football
# 921   St Louis     1904       Football         Football
# 922   St Louis     1904       Football         Football
# 923   St Louis     1904       Football         Football
# 924   St Louis     1904       Football         Football
# 925   St Louis     1904       Football         Football
# 926   St Louis     1904       Football         Football
# 927   St Louis     1904       Football         Football
# 928   St Louis     1904       Football         Football
# 929   St Louis     1904       Football         Football
# 930   St Louis     1904       Football         Football
# 931   St Louis     1904       Football         Football
# 932   St Louis     1904       Football         Football
# 933   St Louis     1904           Golf             Golf
# 934   St Louis     1904           Golf             Golf
# 935   St Louis     1904           Golf             Golf
# 936   St Louis     1904           Golf             Golf
# 937   St Louis     1904           Golf             Golf
# 938   St Louis     1904           Golf             Golf
# 939   St Louis     1904           Golf             Golf
# 940   St Louis     1904           Golf             Golf
# 941   St Louis     1904           Golf             Golf
# 942   St Louis     1904           Golf             Golf
# 943   St Louis     1904           Golf             Golf
# 944   St Louis     1904           Golf             Golf
# 945   St Louis     1904           Golf             Golf
# 946   St Louis     1904           Golf             Golf
# 947   St Louis     1904           Golf             Golf
# 948   St Louis     1904           Golf             Golf
# 949   St Louis     1904           Golf             Golf
# 950   St Louis     1904           Golf             Golf
# 951   St Louis     1904           Golf             Golf
# 952   St Louis     1904           Golf             Golf
# 953   St Louis     1904           Golf             Golf
# 954   St Louis     1904           Golf             Golf
# 955   St Louis     1904           Golf             Golf
# 956   St Louis     1904           Golf             Golf
# 957   St Louis     1904     Gymnastics      Artistic G.
# 958   St Louis     1904     Gymnastics      Artistic G.
# 959   St Louis     1904     Gymnastics      Artistic G.
# 960   St Louis     1904     Gymnastics      Artistic G.
# 961   St Louis     1904     Gymnastics      Artistic G.
# 962   St Louis     1904     Gymnastics      Artistic G.
# 963   St Louis     1904     Gymnastics      Artistic G.
# 964   St Louis     1904     Gymnastics      Artistic G.
# 965   St Louis     1904     Gymnastics      Artistic G.
# 966   St Louis     1904     Gymnastics      Artistic G.
# 967   St Louis     1904     Gymnastics      Artistic G.
# 968   St Louis     1904     Gymnastics      Artistic G.
# 969   St Louis     1904     Gymnastics      Artistic G.
# 970   St Louis     1904     Gymnastics      Artistic G.
# 971   St Louis     1904     Gymnastics      Artistic G.
# 972   St Louis     1904     Gymnastics      Artistic G.
# 973   St Louis     1904     Gymnastics      Artistic G.
# 974   St Louis     1904     Gymnastics      Artistic G.
# 975   St Louis     1904     Gymnastics      Artistic G.
# 976   St Louis     1904     Gymnastics      Artistic G.
# 977   St Louis     1904     Gymnastics      Artistic G.
# 978   St Louis     1904     Gymnastics      Artistic G.
# 979   St Louis     1904     Gymnastics      Artistic G.
# 980   St Louis     1904     Gymnastics      Artistic G.
# 981   St Louis     1904     Gymnastics      Artistic G.
# 982   St Louis     1904     Gymnastics      Artistic G.
# 983   St Louis     1904     Gymnastics      Artistic G.
# 984   St Louis     1904     Gymnastics      Artistic G.
# 985   St Louis     1904     Gymnastics      Artistic G.
# 986   St Louis     1904     Gymnastics      Artistic G.
# 987   St Louis     1904     Gymnastics      Artistic G.
# 988   St Louis     1904     Gymnastics      Artistic G.
# 989   St Louis     1904     Gymnastics      Artistic G.
# 990   St Louis     1904     Gymnastics      Artistic G.
# 991   St Louis     1904     Gymnastics      Artistic G.
# 992   St Louis     1904     Gymnastics      Artistic G.
# 993   St Louis     1904     Gymnastics      Artistic G.
# 994   St Louis     1904     Gymnastics      Artistic G.
# 995   St Louis     1904     Gymnastics      Artistic G.
# 996   St Louis     1904     Gymnastics      Artistic G.
# 997   St Louis     1904     Gymnastics      Artistic G.
# 998   St Louis     1904     Gymnastics      Artistic G.
# 999   St Louis     1904     Gymnastics      Artistic G.
# 1000  St Louis     1904     Gymnastics      Artistic G.
# 1001  St Louis     1904     Gymnastics      Artistic G.
# 1002  St Louis     1904     Gymnastics      Artistic G.
# 1003  St Louis     1904     Gymnastics      Artistic G.
# ...
# 13904  Montreal     1976   Aquatics           Diving  VAYTSEKHOVSKAYA, Elena
# ...         ...      ...        ...              ...                     ...
# 15200  Montreal     1976  Wrestling  Wrestling Gre-R       REZANTSEV, Valeri
# 15201  Montreal     1976  Wrestling  Wrestling Gre-R          IVANOV, Stoyan
# 15202  Montreal     1976  Wrestling  Wrestling Gre-R   SKRZYDLEWSKI, Andrzej
# 15203  Montreal     1976  Wrestling  Wrestling Gre-R      BALBOSHIN, Nikolai
# 15204  Montreal     1976  Wrestling  Wrestling Gre-R          GORANOV, Kamen
#
#        NOC Gender                          Event Event_gender   Medal
# 13900  URS    Men                   10m platform            M  Bronze
# 13901  ITA    Men                   10m platform            M    Gold
# 13902  USA    Men                   10m platform            M  Silver
# 13903  USA  Women                   10m platform            W  Bronze
# 13904  URS  Women                   10m platform            W    Gold
# ...    ...    ...                            ...          ...     ...
# 15200  URS    Men  82 - 90kg (light-heavyweight)            M    Gold
# 15201  BUL    Men  82 - 90kg (light-heavyweight)            M  Silver
# 15202  POL    Men       90 - 100kg (heavyweight)            M  Bronze
# 15203  URS    Men       90 - 100kg (heavyweight)            M    Gold
# 15204  BUL    Men       90 - 100kg (heavyweight)            M  Silver
#
# [1305 rows x 10 columns]
# 1980
#          City  Edition      Sport       Discipline              Athlete  NOC  \
# 15205  Moscow     1980   Aquatics           Diving  AMBARTSUMYAN, David  URS
# 15206  Moscow     1980   Aquatics           Diving       HOFFMANN, Falk  GDR
# 15207  Moscow     1980   Aquatics           Diving    ALEINIK, Vladimir  URS
# 15208  Moscow     1980   Aquatics           Diving      TSOTADZE, Liana  URS
# 15209  Moscow     1980   Aquatics           Diving     JÄSCHKE, Martina  GDR
# ...       ...      ...        ...              ...                  ...  ...
# 16587  Moscow     1980  Wrestling  Wrestling Gre-R      NOTTNY, Norbert  HUN
# 16588  Moscow     1980  Wrestling  Wrestling Gre-R        KANYGIN, Igor  URS
# 16589  Moscow     1980  Wrestling  Wrestling Gre-R       ANDREI, Vasile  ROU
# 16590  Moscow     1980  Wrestling  Wrestling Gre-R       RAIKOV, Georgi  BUL
# 16591  Moscow     1980  Wrestling  Wrestling Gre-R        BIERLA, Roman  POL
#
#       Gender                          Event Event_gender   Medal
# 15205    Men                   10m platform            M  Bronze
# 15206    Men                   10m platform            M    Gold
# 15207    Men                   10m platform            M  Silver
# 15208  Women                   10m platform            W  Bronze
# 15209  Women                   10m platform            W    Gold
# ...      ...                            ...          ...     ...
# 16587    Men  82 - 90kg (light-heavyweight)            M    Gold
# 16588    Men  82 - 90kg (light-heavyweight)            M  Silver
# 16589    Men       90 - 100kg (heavyweight)            M  Bronze
# 16590    Men       90 - 100kg (heavyweight)            M    Gold
# 16591    Men       90 - 100kg (heavyweight)            M  Silver
#
# [1387 rows x 10 columns]
# 1984
#               City  Edition      Sport       Discipline  \
# 16592  Los Angeles     1984   Aquatics           Diving
# 16593  Los Angeles     1984   Aquatics           Diving
# 16594  Los Angeles     1984   Aquatics           Diving
# 16595  Los Angeles     1984   Aquatics           Diving
# 16596  Los Angeles     1984   Aquatics           Diving
# ...            ...      ...        ...              ...
# 18046  Los Angeles     1984  Wrestling  Wrestling Gre-R
# 18047  Los Angeles     1984  Wrestling  Wrestling Gre-R
# 18048  Los Angeles     1984  Wrestling  Wrestling Gre-R
# 18049  Los Angeles     1984  Wrestling  Wrestling Gre-R
# 18050  Los Angeles     1984  Wrestling  Wrestling Gre-R
#
#                            Athlete  NOC Gender                          Event  \
# 16592               LI, Kong-Zheng  CHN    Men                   10m platform
# 16593            LOUGANIS, Gregory  USA    Men                   10m platform
# 16594            KIMBALL, Bruce D.  USA    Men                   10m platform
# 16595  WYLAND-WILLIAMS, Wendy Lian  USA  Women                   10m platform
# 16596                ZHOU, Ji-Hong  CHN  Women                   10m platform
# ...                            ...  ...    ...                            ...
# 18046        FRASER, Steven Howard  USA    Men  82 - 90kg (light-heavyweight)
# 18047                  MATEI, Ilie  ROU    Men  82 - 90kg (light-heavyweight)
# 18048             TERTELIJE, Jozef  YUG    Men       90 - 100kg (heavyweight)
# 18049               ANDREI, Vasile  ROU    Men       90 - 100kg (heavyweight)
# 18050           GIBSON, Gregory P.  USA    Men       90 - 100kg (heavyweight)
#
#       Event_gender   Medal
# 16592            M  Bronze
# 16593            M    Gold
# 16594            M  Silver
# 16595            W  Bronze
# 16596            W    Gold
# ...            ...     ...
# 18046            M    Gold
# 18047            M  Silver
# 18048            M  Bronze
# 18049            M    Gold
# 18050            M  Silver
#
# [1459 rows x 10 columns]
# 1988
#         City  Edition      Sport       Discipline  \
# 18051  Seoul     1988   Aquatics           Diving
# 18052  Seoul     1988   Aquatics           Diving
# 18053  Seoul     1988   Aquatics           Diving
# 18054  Seoul     1988   Aquatics           Diving
# 18055  Seoul     1988   Aquatics           Diving
# ...      ...      ...        ...              ...
# 19592  Seoul     1988  Wrestling  Wrestling Gre-R
# 19593  Seoul     1988  Wrestling  Wrestling Gre-R
# 19594  Seoul     1988  Wrestling  Wrestling Gre-R
# 19595  Seoul     1988  Wrestling  Wrestling Gre-R
# 19596  Seoul     1988  Wrestling  Wrestling Gre-R
#
#                            Athlete  NOC Gender                          Event  \
# 18051           MENA CAMPOS, Jesus  MEX    Men                   10m platform
# 18052            LOUGANIS, Gregory  USA    Men                   10m platform
# 18053                    XIONG, Ni  CHN    Men                   10m platform
# 18054  WYLAND-WILLIAMS, Wendy Lian  USA  Women                   10m platform
# 18055                  XU, Yan-Mei  CHN  Women                   10m platform
# ...                            ...  ...    ...                            ...
# 19592       KOMCHEV, Atanas Slavov  BUL    Men  82 - 90kg (light-heavyweight)
# 19593        KOSKELA, Harri Matias  FIN    Men  82 - 90kg (light-heavyweight)
# 19594     KOSLOWSKI, Dennis Marvin  USA    Men       90 - 100kg (heavyweight)
# 19595             WRONSKI, Andrzej  POL    Men       90 - 100kg (heavyweight)
# 19596              HIMMEL, Gerhard  FRG    Men       90 - 100kg (heavyweight)
#
#       Event_gender   Medal
# 18051            M  Bronze
# 18052            M    Gold
# 18053            M  Silver
# 18054            W  Bronze
# 18055            W    Gold
# ...            ...     ...
# 19592            M    Gold
# 19593            M  Silver
# 19594            M  Bronze
# 19595            M    Gold
# 19596            M  Silver
#
# [1546 rows x 10 columns]
# 1992
#             City  Edition      Sport       Discipline  \
# 19597  Barcelona     1992   Aquatics           Diving
# 19598  Barcelona     1992   Aquatics           Diving
# 19599  Barcelona     1992   Aquatics           Diving
# 19600  Barcelona     1992   Aquatics           Diving
# 19601  Barcelona     1992   Aquatics           Diving
# ...          ...      ...        ...              ...
# 21297  Barcelona     1992  Wrestling  Wrestling Gre-R
# 21298  Barcelona     1992  Wrestling  Wrestling Gre-R
# 21299  Barcelona     1992  Wrestling  Wrestling Gre-R
# 21300  Barcelona     1992  Wrestling  Wrestling Gre-R
# 21301  Barcelona     1992  Wrestling  Wrestling Gre-R
#
#                         Athlete  NOC Gender                          Event  \
# 19597                 XIONG, Ni  CHN    Men                   10m platform
# 19598               SUN, Shuwei  CHN    Men                   10m platform
# 19599           DONIE, Scott R.  USA    Men                   10m platform
# 19600         CLARK, Mary Ellen  USA  Women                   10m platform
# 19601               FU, Mingxia  CHN  Women                   10m platform
# ...                         ...  ...    ...                            ...
# 21297            BULLMANN, Maik  GER    Men  82 - 90kg (light-heavyweight)
# 21298              BASAR, Hakki  TUR    Men  82 - 90kg (light-heavyweight)
# 21299  DEMIACHKIEVITCH, Serguei  EUN    Men       90 - 100kg (heavyweight)
# 21300      MILIAN PEREZ, Hector  CUB    Men       90 - 100kg (heavyweight)
# 21301  KOSLOWSKI, Dennis Marvin  USA    Men       90 - 100kg (heavyweight)
#
#       Event_gender   Medal
# 19597            M  Bronze
# 19598            M    Gold
# 19599            M  Silver
# 19600            W  Bronze
# 19601            W    Gold
# ...            ...     ...
# 21297            M    Gold
# 21298            M  Silver
# 21299            M  Bronze
# 21300            M    Gold
# 21301            M  Silver
#
# [1705 rows x 10 columns]
# 1996
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 21302  Atlanta     1996   Aquatics           Diving       XIAO, Hailiang  CHN
# 21303  Atlanta     1996   Aquatics           Diving       SAUTIN, Dmitry  RUS
# 21304  Atlanta     1996   Aquatics           Diving          HEMPEL, Jan  GER
# 21305  Atlanta     1996   Aquatics           Diving    CLARK, Mary Ellen  USA
# 21306  Atlanta     1996   Aquatics           Diving          FU, Mingxia  CHN
# ...        ...      ...        ...              ...                  ...  ...
# 23156  Atlanta     1996  Wrestling  Wrestling Gre-R  OLEYNYK, Vyacheslav  UKR
# 23157  Atlanta     1996  Wrestling  Wrestling Gre-R      FAFINSKI, Jacek  POL
# 23158  Atlanta     1996  Wrestling  Wrestling Gre-R    LJUNGBERG, Mikael  SWE
# 23159  Atlanta     1996  Wrestling  Wrestling Gre-R     WRONSKI, Andrzej  POL
# 23160  Atlanta     1996  Wrestling  Wrestling Gre-R     LISHTVAN, Sergey  BLR
#
#       Gender                          Event Event_gender   Medal
# 21302    Men                   10m platform            M  Bronze
# 21303    Men                   10m platform            M    Gold
# 21304    Men                   10m platform            M  Silver
# 21305  Women                   10m platform            W  Bronze
# 21306  Women                   10m platform            W    Gold
# ...      ...                            ...          ...     ...
# 23156    Men  82 - 90kg (light-heavyweight)            M    Gold
# 23157    Men  82 - 90kg (light-heavyweight)            M  Silver
# 23158    Men       90 - 100kg (heavyweight)            M  Bronze
# 23159    Men       90 - 100kg (heavyweight)            M    Gold
# 23160    Men       90 - 100kg (heavyweight)            M  Silver
#
# [1859 rows x 10 columns]
# 2000
#          City  Edition      Sport       Discipline                   Athlete  \
# 23161  Sydney     2000   Aquatics           Diving            SAUTIN, Dmitry
# 23162  Sydney     2000   Aquatics           Diving               TIAN, Liang
# 23163  Sydney     2000   Aquatics           Diving                   HU, Jia
# 23164  Sydney     2000   Aquatics           Diving  MONTMINY, Anne Katherine
# 23165  Sydney     2000   Aquatics           Diving          WILKINSON, Laura
# ...       ...      ...        ...              ...                       ...
# 25171  Sydney     2000  Wrestling  Wrestling Gre-R         LJUNGBERG, Mikael
# 25172  Sydney     2000  Wrestling  Wrestling Gre-R           SALDADZE, Davyd
# 25173  Sydney     2000  Wrestling  Wrestling Gre-R           DEBELKA, Dmitry
# 25174  Sydney     2000  Wrestling  Wrestling Gre-R            GARDNER, Rulon
# 25175  Sydney     2000  Wrestling  Wrestling Gre-R        KARELIN, Aleksandr
#
#        NOC Gender         Event Event_gender   Medal
# 23161  RUS    Men  10m platform            M  Bronze
# 23162  CHN    Men  10m platform            M    Gold
# 23163  CHN    Men  10m platform            M  Silver
# 23164  CAN  Women  10m platform            W  Bronze
# 23165  USA  Women  10m platform            W    Gold
# ...    ...    ...           ...          ...     ...
# 25171  SWE    Men     85 - 97kg            M    Gold
# 25172  UKR    Men     85 - 97kg            M  Silver
# 25173  BLR    Men    97 - 130kg            M  Bronze
# 25174  USA    Men    97 - 130kg            M    Gold
# 25175  RUS    Men    97 - 130kg            M  Silver
#
# [2015 rows x 10 columns]
# 2004
#          City  Edition      Sport       Discipline               Athlete  NOC  \
# 25176  Athens     2004   Aquatics           Diving           TIAN, Liang  CHN
# 25177  Athens     2004   Aquatics           Diving               HU, Jia  CHN
# 25178  Athens     2004   Aquatics           Diving          HELM, Mathew  AUS
# 25179  Athens     2004   Aquatics           Diving         TOURKY, Loudy  AUS
# 25180  Athens     2004   Aquatics           Diving    NEWBERY, Chantelle  AUS
# ...       ...      ...        ...              ...                   ...  ...
# 27169  Athens     2004  Wrestling  Wrestling Gre-R  GABER IBRAHIM, Karam  EGY
# 27170  Athens     2004  Wrestling  Wrestling Gre-R        NOZADZE, Ramaz  GEO
# 27171  Athens     2004  Wrestling  Wrestling Gre-R        GARDNER, Rulon  USA
# 27172  Athens     2004  Wrestling  Wrestling Gre-R        BAROEV, Khasan  RUS
# 27173  Athens     2004  Wrestling  Wrestling Gre-R   TSURTSUMIA, Georgiy  KAZ
#
#       Gender         Event Event_gender   Medal
# 25176    Men  10m platform            M  Bronze
# 25177    Men  10m platform            M    Gold
# 25178    Men  10m platform            M  Silver
# 25179  Women  10m platform            W  Bronze
# 25180  Women  10m platform            W    Gold
# ...      ...           ...          ...     ...
# 27169    Men     84 - 96kg            M    Gold
# 27170    Men     84 - 96kg            M  Silver
# 27171    Men    96 - 120kg            M  Bronze
# 27172    Men    96 - 120kg            M    Gold
# 27173    Men    96 - 120kg            M  Silver
#
# [1998 rows x 10 columns]
# 2008
#           City  Edition      Sport       Discipline               Athlete  \
# 27174  Beijing     2008   Aquatics           Diving        GALPERIN, Gleb
# 27175  Beijing     2008   Aquatics           Diving      MITCHAM, Matthew
# 27176  Beijing     2008   Aquatics           Diving           ZHOU, Luxin
# 27177  Beijing     2008   Aquatics           Diving             WANG, Xin
# 27178  Beijing     2008   Aquatics           Diving          CHEN, Ruolin
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender         Event Event_gender   Medal
# 27174  RUS    Men  10m platform            M  Bronze
# 27175  AUS    Men  10m platform            M    Gold
# 27176  CHN    Men  10m platform            M  Silver
# 27177  CHN  Women  10m platform            W  Bronze
# 27178  CHN  Women  10m platform            W    Gold
# ...    ...    ...           ...          ...     ...
# 29211  GER    Men     84 - 96kg            M  Silver
# 29212  LTU    Men    96 - 120kg            M  Bronze
# 29213  ARM    Men    96 - 120kg            M  Bronze
# 29214  CUB    Men    96 - 120kg            M    Gold
# 29215  RUS    Men    96 - 120kg            M  Silver
#
# [2042 rows x 10 columns]

# %%
type(group_val)
# Out:
# pandas.core.frame.DataFrame

# %%
oo.groupby('Edition').size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
oo.groupby(['Edition', 'NOC', 'Medal']).agg(['min', 'max', 'count'])
# Out:
#                        City                         Sport                 \
#                         min      max count            min            max
# Edition NOC Medal
# 1896    AUS Gold     Athens   Athens     2      Athletics      Athletics
#         AUT Bronze   Athens   Athens     2        Cycling        Cycling
#             Gold     Athens   Athens     2       Aquatics        Cycling
#             Silver   Athens   Athens     1       Aquatics       Aquatics
#         DEN Bronze   Athens   Athens     3        Fencing       Shooting
# ...                     ...      ...   ...            ...            ...
# 2008    UZB Silver  Beijing  Beijing     2           Judo      Wrestling
#         VEN Bronze  Beijing  Beijing     1      Taekwondo      Taekwondo
#         VIE Silver  Beijing  Beijing     1  Weightlifting  Weightlifting
#         ZIM Gold    Beijing  Beijing     1       Aquatics       Aquatics
#             Silver  Beijing  Beijing     3       Aquatics       Aquatics
#
#                              Discipline                         \
#                    count            min              max count
# Edition NOC Medal
# 1896    AUS Gold       2      Athletics        Athletics     2
#         AUT Bronze     2  Cycling Track    Cycling Track     2
#             Gold       2  Cycling Track         Swimming     2
#             Silver     1       Swimming         Swimming     1
#         DEN Bronze     3        Fencing         Shooting     3
# ...                  ...            ...              ...   ...
# 2008    UZB Silver     2           Judo  Wrestling Free.     2
#         VEN Bronze     1      Taekwondo        Taekwondo     1
#         VIE Silver     1  Weightlifting    Weightlifting     1
#         ZIM Gold       1       Swimming         Swimming     1
#             Silver     3       Swimming         Swimming     3
#
#                                     Athlete  ...       Gender               \
#                                         min  ... count    min    max count
# Edition NOC Medal                            ...
# 1896    AUS Gold               FLACK, Edwin  ...     2    Men    Men     2
#         AUT Bronze            SCHMAL, Adolf  ...     2    Men    Men     2
#             Gold              NEUMANN, Paul  ...     2    Men    Men     2
#             Silver         HERSCHMANN, Otto  ...     1    Men    Men     1
#         DEN Bronze            JENSEN, Viggo  ...     3    Men    Men     3
# ...                                     ...  ...   ...    ...    ...   ...
# 2008    UZB Silver        TANGRIEV, Abdullo  ...     2    Men    Men     2
#         VEN Bronze  CONTRERAS RIVERO, Dalia  ...     1  Women  Women     1
#         VIE Silver          HOANG, Anh Tuan  ...     1    Men    Men     1
#         ZIM Gold           COVENTRY, Kirsty  ...     1  Women  Women     1
#             Silver         COVENTRY, Kirsty  ...     3  Women  Women     3
#
#                                                Event  \
#                                                  min
# Edition NOC Medal
# 1896    AUS Gold                               1500m
#         AUT Bronze                              10km
#             Gold                        12-hour race
#             Silver                    100m freestyle
#         DEN Bronze  25m rapid fire pistol (60 shots)
# ...                                              ...
# 2008    UZB Silver             + 100kg (heavyweight)
#         VEN Bronze                           - 49 kg
#         VIE Silver      - 56kg, total (bantamweight)
#         ZIM Gold                     200m backstroke
#             Silver                   100m backstroke
#
#                                                        Event_gender
#                                              max count          min max count
# Edition NOC Medal
# 1896    AUS Gold                            800m     2            M   M     2
#         AUT Bronze                1km time trial     2            M   M     2
#             Gold                  400m freestyle     2            M   M     2
#             Silver                100m freestyle     1            M   M     1
#         DEN Bronze              sabre individual     3            M   M     3
# ...                                          ...   ...          ...  ..   ...
# 2008    UZB Silver                     66 - 74kg     2            M   M     2
#         VEN Bronze                       - 49 kg     1            W   W     1
#         VIE Silver  - 56kg, total (bantamweight)     1            M   M     1
#         ZIM Gold                 200m backstroke     1            W   W     1
#             Silver        400m individual medley     3            W   W     3
#
# [2356 rows x 21 columns]

# %%
oo.groupby(['Edition', 'NOC', 'Medal']).agg({'Edition':['min', 'max', 'count']})
# Out:
#                    Edition
#                        min   max count
# Edition NOC Medal
# 1896    AUS Gold      1896  1896     2
#         AUT Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     1
#         DEN Bronze    1896  1896     3
# ...                    ...   ...   ...
# 2008    UZB Silver    2008  2008     2
#         VEN Bronze    2008  2008     1
#         VIE Silver    2008  2008     1
#         ZIM Gold      2008  2008     1
#             Silver    2008  2008     3
#
# [2356 rows x 3 columns]

# %%
oo.loc[oo.Athlete == 'LEWIS, Carl'].groupby('Athlete').agg({'Edition':['min', 'max', 'count']})
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %%
oo.groupby('Edition').size().plot()
# Out:
# <AxesSubplot: xlabel='Edition'>

# %%
oo.groupby('NOC').agg({'Edition':['count', 'min', 'max']})
# Out:
#     Edition
#       count   min   max
# NOC
# AFG       1  2008  2008
# AHO       1  1988  1988
# ALG      14  1984  2008
# ANZ      29  1908  1912
# ARG     239  1924  2008
# ARM       9  1996  2008
# AUS    1075  1896  2008
# AUT     146  1896  2008
# AZE      16  1996  2008
# BAH      23  1956  2008
# BAR       1  2000  2000
# BDI       1  1996  1996
# BEL     408  1900  2008
# BER       1  1976  1976
# BLR      92  1996  2008
# BOH       7  1900  1908
# BRA     372  1920  2008
# BUL     331  1952  2008
# BWI       5  1960  1960
# CAN     592  1900  2008
# CHI      33  1928  2008
# CHN     679  1984  2008
# CIV       1  1984  1984
# CMR      22  1968  2008
# COL      11  1972  2008
# CRC       4  1988  2000
# CRO      79  1992  2008
# CUB     395  1900  2008
# CZE      41  1996  2008
# DEN     491  1896  2008
# DJI       1  1988  1988
# DOM       4  1984  2008
# ECU       2  1996  2008
# EGY      24  1928  2008
# ERI       1  2004  2004
# ESP     377  1900  2008
# EST      37  1920  2008
# ETH      38  1960  2008
# EUA     260  1956  1964
# EUN     223  1992  1992
# FIN     451  1908  2008
# FRA    1314  1896  2008
# FRG     490  1968  1988
# GBR    1594  1896  2008
# GDR     825  1968  1988
# GEO      18  1996  2008
# GER    1211  1896  2008
# GHA      16  1960  1992
# GRE     145  1896  2008
# GUY       1  1980  1980
# HAI       8  1924  1928
# HKG       3  1996  2004
# HUN    1053  1896  2008
# INA      35  1988  2008
# IND     178  1900  2008
# IOP       3  1992  1992
# IRI      48  1948  2008
# IRL      24  1928  2008
# IRQ       1  1960  1960
# ISL      17  1956  2008
# ISR       7  1992  2008
# ISV       1  1988  1988
# ITA    1228  1900  2008
# JAM     102  1948  2008
# JPN     704  1920  2008
# KAZ      39  1996  2008
# KEN      81  1964  2008
# KGZ       3  2000  2008
# KOR     466  1948  2008
# KSA       2  2000  2000
# KUW       1  2000  2000
# LAT      17  1932  2008
# LIB       4  1952  1980
# LTU      50  1992  2008
# LUX       2  1920  1952
# MAR      21  1960  2008
# MAS       6  1992  2008
# MDA       6  1996  2008
# MEX      80  1932  2008
# MGL      19  1968  2008
# MKD       1  2000  2000
# MOZ       2  1996  2000
# MRI       1  2008  2008
# NAM       4  1992  1996
# NED     782  1900  2008
# NGR      84  1964  2008
# NIG       1  1972  1972
# NOR     537  1900  2008
# NZL     164  1920  2008
# PAK     121  1956  1992
# PAN       3  1948  2008
# PAR      17  2004  2004
# PER      15  1948  1992
# PHI       9  1928  1996
# POL     499  1924  2008
# POR      31  1924  2008
# PRK      52  1972  2008
# PUR       6  1948  1996
# QAT       2  1992  2000
# ROU     624  1924  2008
# RSA      97  1908  2008
# RU1      17  1908  1912
# RUS     638  1996  2008
# SCG      14  2004  2004
# SEN       1  1988  1988
# SIN       4  1960  2008
# SLO      21  1992  2008
# SRB      15  2008  2008
# SRI       2  1948  2000
# SUD       1  2008  2008
# SUI     376  1896  2008
# SUR       2  1988  1992
# SVK      29  1996  2008
# SWE    1021  1900  2008
# SYR       3  1984  2004
# TAN       2  1980  1980
# TCH     329  1920  1992
# TGA       1  1996  1996
# THA      21  1976  2008
# TJK       2  2008  2008
# TOG       1  2008  2008
# TPE      42  1960  2008
# TRI      20  1948  2008
# TUN       7  1964  2008
# TUR      82  1936  2008
# UAE       1  2004  2004
# UGA       6  1968  1996
# UKR     148  1996  2008
# URS    2049  1952  1988
# URU      76  1924  2000
# USA    4335  1896  2008
# UZB      17  1996  2008
# VEN      11  1952  2008
# VIE       2  2000  2008
# YUG     435  1924  2000
# ZAM       2  1984  1996
# ZIM      23  1980  2008
# ZZX      48  1896  1904
