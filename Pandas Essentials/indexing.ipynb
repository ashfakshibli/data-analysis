# %% [markdown]
# # Indexing

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
oo = pd.read_csv("data/olympics.csv", skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
type(oo.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# ## set_index()

# %%
oo.set_index('Athlete').head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.set_index('Athlete', inplace=True)

# %%
oo.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo.reset_index(inplace=True)
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
ath = oo.set_index('Athlete')
ath.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath.sort_index(inplace=True, ascending=False)

# %%
ath.head()
# Out:
#                        City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# ÖSTRAND, Per-Olof  Helsinki     1952  Aquatics   Swimming  SWE    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
#
#                                            Event Event_gender   Medal
# Athlete
# ÖSTRAND, Per-Olof                 400m freestyle            M  Bronze
# ÖSTMO, Ole                      free rifle, team            M  Silver
# ÖSTMO, Ole            army rifle, 300m, standing            M  Silver
# ÖSTMO, Ole               army rifle, 300m, prone            M  Bronze
# ÖSTMO, Ole         army rifle, 300m, 3 positions            M  Bronze

# %%
ath.loc['BOLT, Usain']
# Out:
#                 City  Edition      Sport Discipline  NOC Gender         Event  \
# Athlete
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men  4x100m relay
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          200m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          100m
#
#             Event_gender Medal
# Athlete
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold

# %%
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.loc[oo.Athlete == 'BOLT, Usain']
# Out:
#            Athlete     City  Edition      Sport Discipline  NOC Gender  \
# 27552  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27570  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27603  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
#
#               Event Event_gender Medal
# 27552          100m            M  Gold
# 27570          200m            M  Gold
# 27603  4x100m relay            M  Gold

# %%
oo.iloc[1700]
# Out:
# Athlete         RABOT, Pierre
# City                   London
# Edition                  1908
# Sport                 Sailing
# Discipline            Sailing
# NOC                       FRA
# Gender                    Men
# Event                      6m
# Event_gender                X
# Medal                  Bronze
# Name: 1700, dtype: object

# %%
oo.iloc[[1700, 3408, 6000]]
# Out:
#                Athlete         City  Edition       Sport   Discipline  NOC  \
# 1700     RABOT, Pierre       London     1908     Sailing      Sailing  FRA
# 3408  VERDONCK, Julien      Antwerp     1920  Gymnastics  Artistic G.  BEL
# 6000   AGOSTONI, Carlo  Los Angeles     1932     Fencing      Fencing  ITA
#
#      Gender             Event Event_gender   Medal
# 1700    Men                6m            X  Bronze
# 3408    Men  team competition            M  Silver
# 6000    Men   épée individual            M  Bronze

# %%
oo.iloc[1:4]
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold

# %% [markdown]
# #### Plot the total number of medals till now.

# %%
oo.Edition.value_counts().sort_index().plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### Which country did not win a medal in 2008 and how many countries.

# %%
ol2008 = oo[oo.Edition == 2008]
ol2008.head()
# Out:
#                 Athlete     City  Edition     Sport Discipline  NOC Gender  \
# 27174    GALPERIN, Gleb  Beijing     2008  Aquatics     Diving  RUS    Men
# 27175  MITCHAM, Matthew  Beijing     2008  Aquatics     Diving  AUS    Men
# 27176       ZHOU, Luxin  Beijing     2008  Aquatics     Diving  CHN    Men
# 27177         WANG, Xin  Beijing     2008  Aquatics     Diving  CHN  Women
# 27178      CHEN, Ruolin  Beijing     2008  Aquatics     Diving  CHN  Women
#
#               Event Event_gender   Medal
# 27174  10m platform            M  Bronze
# 27175  10m platform            M    Gold
# 27176  10m platform            M  Silver
# 27177  10m platform            W  Bronze
# 27178  10m platform            W    Gold

# %%
noc = pd.read_csv('data/Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv')
noc.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %%
noc[noc['Country'] != noc['Country.1']]
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
noc.set_index('Int Olympic Committee code', inplace=True)
noc.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
medal_2008 = ol2008.NOC.value_counts()
medal_2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
# KOR     78
# GBR     77
# FRA     76
# BRA     75
# ESP     71
# NED     62
# ARG     51
# JPN     51
# CUB     47
# ITA     42
# CAN     34
# UKR     31
# BLR     30
# HUN     27
# NGR     24
# ROU     22
# NOR     22
# POL     20
# DEN     18
# JAM     17
# SRB     15
# NZL     14
# ISL     14
# KEN     14
# KAZ     13
# SUI     11
# SVK     10
# TUR      8
# CZE      7
# ETH      7
# INA      7
# GRE      7
# SWE      7
# AZE      7
# ARM      6
# GEO      6
# PRK      6
# UZB      6
# SLO      5
# TRI      5
# FIN      5
# CRO      5
# LTU      5
# BAH      5
# BEL      5
# BUL      5
# ZIM      4
# TPE      4
# THA      4
# MGL      4
# MEX      4
# SIN      3
# IND      3
# LAT      3
# EST      3
# IRL      3
# AUT      3
# TJK      2
# COL      2
# IRI      2
# ALG      2
# MAR      2
# KGZ      2
# POR      2
# DOM      2
# PAN      1
# VEN      1
# VIE      1
# CHI      1
# MAS      1
# AFG      1
# CMR      1
# TUN      1
# RSA      1
# ISR      1
# ECU      1
# SUD      1
# EGY      1
# MDA      1
# TOG      1
# MRI      1
# Name: NOC, dtype: int64

# %%
noc['medal_2008'] = medal_2008
noc.head()
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
#
#                             medal_2008
# Int Olympic Committee code
# AFG                                1.0
# ALB                                NaN
# ALG                                2.0
# ASA                                NaN
# AND                                NaN

# %%
noc[noc.medal_2008.isnull()].count()
# Out:
# Country       117
# ISO code      116
# Country.1     117
# medal_2008      0
# dtype: int64

# %%
noc[noc.medal_2008.isnull()]
# Out:
#                                                      Country ISO code  \
# Int Olympic Committee code
# ALB                                                  Albania       AL
# ASA                                          American Samoa*       AS
# AND                                                  Andorra       AD
# ANG                                                   Angola       AO
# ANT                                      Antigua and Barbuda       AG
# ARU                                                   Aruba*       AW
# BRN                                                  Bahrain       BH
# BAN                                               Bangladesh       BD
# BAR                                                 Barbados       BB
# BIZ                                                   Belize       BZ
# BER                                                 Bermuda*       BM
# BEN                                                    Benin       BJ
# BHU                                                   Bhutan       BT
# BOL                                                  Bolivia       BO
# BIH                                   Bosnia and Herzegovina       BA
# BOT                                                 Botswana       BW
# IVB                                   British Virgin Islands       VG
# BRU                                                   Brunei       BN
# BUR                                             Burkina Faso       BF
# BDI                                                  Burundi       BI
# CAM                                                 Cambodia       KH
# CPV                                               Cape Verde       CV
# CAY                                          Cayman Islands*       KY
# CAF                                 Central African Republic       CF
# CHA                                                     Chad       TD
# COM                                                  Comoros       KM
# CGO                                                    Congo       CG
# COD                                           Congo, Dem Rep       CD
# COK                                             Cook Islands       CK
# CRC                                               Costa Rica       CR
# CIV                                            Cote d'Ivoire       CI
# CYP                                                   Cyprus       CY
# DJI                                                 Djibouti       DJ
# DMA                                                 Dominica       DM
# TLS                                 East Timor (Timor-Leste)       TL
# ESA                                              El Salvador       SV
# GEQ                                        Equatorial Guinea       GQ
# ERI                                                  Eritrea       ER
# FIJ                                                     Fiji       FJ
# GAB                                                    Gabon       GA
# GAM                                                   Gambia       GM
# GHA                                                    Ghana       GH
# GRN                                                  Grenada       GD
# GUM                                                     Guam       GU
# GUA                                                Guatemala       GT
# GUI                                                   Guinea       GN
# GBS                                            Guinea-Bissau       GW
# GUY                                                   Guyana       GY
# HAI                                                    Haiti       HT
# HON                                                 Honduras       HN
# HKG                                               Hong Kong*       HK
# IRQ                                                     Iraq       IQ
# JOR                                                   Jordan       JO
# KUW                                                   Kuwait       KW
# LAO                                                     Laos       LA
# LIB                                                  Lebanon       LB
# LES                                                  Lesotho       LS
# LBR                                                  Liberia       LR
# LBA                                                    Libya       LY
# LIE                                            Liechtenstein       LI
# LUX                                               Luxembourg       LU
# MKD                                                Macedonia       MK
# MAD                                               Madagascar       MG
# MAW                                                   Malawi       MW
# MDV                                                 Maldives       MV
# MLI                                                     Mali       ML
# MLT                                                    Malta       MT
# MTN                                               Mauritania       MR
# FSM                                               Micronesia       FM
# MON                                                   Monaco       MC
# MOZ                                               Mozambique       MZ
# MYA                                                    Burma       MM
# NAM                                                  Namibia      NaN
# NRU                                                    Nauru       NR
# NEP                                                    Nepal       NP
# AHO                                    Netherlands Antilles*       AN
# NCA                                                Nicaragua       NI
# NIG                                                    Niger       NE
# OMA                                                     Oman       OM
# PAK                                                 Pakistan       PK
# PLW                                                    Palau       PW
# PLE                          Palestine, Occupied Territories       PS
# PNG                                         Papua New Guinea       PG
# PAR                                                 Paraguay       PY
# PER                                                     Peru       PE
# PHI                                              Philippines       PH
# PUR                                             Puerto Rico*       PR
# QAT                                                    Qatar       QA
# ROM                                                  Romania       RO
# RWA                                                   Rwanda       RW
# SKN                                    Saint Kitts and Nevis       KN
# LCA                                              Saint Lucia       LC
# VIN                         Saint Vincent and the Grenadines       VC
# SAM                                                    Samoa       WS
# SMR                                               San Marino       SM
# STP                                    Sao Tome and Principe       ST
# KSA                                             Saudi Arabia       SA
# SEN                                                  Senegal       SN
# SCG                                                   Serbia       RS
# SEY                                               Seychelles       SC
# SLE                                             Sierra Leone       SL
# SOL                                          Solomon Islands       SB
# SOM                                                  Somalia       SO
# SRI                                                Sri Lanka       LK
# SUR                                                 Suriname       SR
# SWZ                                                Swaziland       SZ
# SYR                                                    Syria       SY
# TAN                                                 Tanzania       TZ
# TGA                                                    Tonga       TO
# TKM                                             Turkmenistan       TM
# UGA                                                   Uganda       UG
# UAE                                     United Arab Emirates       AE
# URU                                                  Uruguay       UY
# VAN                                                  Vanuatu       VU
# ISV                                          Virgin Islands*       VI
# YEM                                                    Yemen       YE
# ZAM                                                   Zambia       ZM
#
#                                                    Country.1  medal_2008
# Int Olympic Committee code
# ALB                                                  Albania         NaN
# ASA                                          American Samoa*         NaN
# AND                                                  Andorra         NaN
# ANG                                                   Angola         NaN
# ANT                                      Antigua and Barbuda         NaN
# ARU                                                   Aruba*         NaN
# BRN                                                  Bahrain         NaN
# BAN                                               Bangladesh         NaN
# BAR                                                 Barbados         NaN
# BIZ                                                   Belize         NaN
# BER                                                 Bermuda*         NaN
# BEN                                                    Benin         NaN
# BHU                                                   Bhutan         NaN
# BOL                                                  Bolivia         NaN
# BIH                                   Bosnia and Herzegovina         NaN
# BOT                                                 Botswana         NaN
# IVB                                   British Virgin Islands         NaN
# BRU                                                   Brunei         NaN
# BUR                                             Burkina Faso         NaN
# BDI                                                  Burundi         NaN
# CAM                                                 Cambodia         NaN
# CPV                                               Cape Verde         NaN
# CAY                                          Cayman Islands*         NaN
# CAF                                 Central African Republic         NaN
# CHA                                                     Chad         NaN
# COM                                                  Comoros         NaN
# CGO                                                    Congo         NaN
# COD                                           Congo, Dem Rep         NaN
# COK                                             Cook Islands         NaN
# CRC                                               Costa Rica         NaN
# CIV                                            Cote d'Ivoire         NaN
# CYP                                                   Cyprus         NaN
# DJI                                                 Djibouti         NaN
# DMA                                                 Dominica         NaN
# TLS                                 East Timor (Timor-Leste)         NaN
# ESA                                              El Salvador         NaN
# GEQ                                        Equatorial Guinea         NaN
# ERI                                                  Eritrea         NaN
# FIJ                                                     Fiji         NaN
# GAB                                                    Gabon         NaN
# GAM                                                   Gambia         NaN
# GHA                                                    Ghana         NaN
# GRN                                                  Grenada         NaN
# GUM                                                     Guam         NaN
# GUA                                                Guatemala         NaN
# GUI                                                   Guinea         NaN
# GBS                                            Guinea-Bissau         NaN
# GUY                                                   Guyana         NaN
# HAI                                                    Haiti         NaN
# HON                                                 Honduras         NaN
# HKG                                               Hong Kong*         NaN
# IRQ                                                     Iraq         NaN
# JOR                                                   Jordan         NaN
# KUW                                                   Kuwait         NaN
# LAO                                                     Laos         NaN
# LIB                                                  Lebanon         NaN
# LES                                                  Lesotho         NaN
# LBR                                                  Liberia         NaN
# LBA                                                    Libya         NaN
# LIE                                            Liechtenstein         NaN
# LUX                                               Luxembourg         NaN
# MKD                                                Macedonia         NaN
# MAD                                               Madagascar         NaN
# MAW                                                   Malawi         NaN
# MDV                                                 Maldives         NaN
# MLI                                                     Mali         NaN
# MLT                                                    Malta         NaN
# MTN                                               Mauritania         NaN
# FSM                                               Micronesia         NaN
# MON                                                   Monaco         NaN
# MOZ                                               Mozambique         NaN
# MYA                                                    Burma         NaN
# NAM                                                  Namibia         NaN
# NRU                                                    Nauru         NaN
# NEP                                                    Nepal         NaN
# AHO                                    Netherlands Antilles*         NaN
# NCA                                                Nicaragua         NaN
# NIG                                                    Niger         NaN
# OMA                                                     Oman         NaN
# PAK                                                 Pakistan         NaN
# PLW                                                    Palau         NaN
# PLE                          Palestine, Occupied Territories         NaN
# PNG                                         Papua New Guinea         NaN
# PAR                                                 Paraguay         NaN
# PER                                                     Peru         NaN
# PHI                                              Philippines         NaN
# PUR                                             Puerto Rico*         NaN
# QAT                                                    Qatar         NaN
# ROM                                                  Romania         NaN
# RWA                                                   Rwanda         NaN
# SKN                                    Saint Kitts and Nevis         NaN
# LCA                                              Saint Lucia         NaN
# VIN                         Saint Vincent and the Grenadines         NaN
# SAM                                                    Samoa         NaN
# SMR                                               San Marino         NaN
# STP                                    Sao Tome and Principe         NaN
# KSA                                             Saudi Arabia         NaN
# SEN                                                  Senegal         NaN
# SCG                                                   Serbia         NaN
# SEY                                               Seychelles         NaN
# SLE                                             Sierra Leone         NaN
# SOL                                          Solomon Islands         NaN
# SOM                                                  Somalia         NaN
# SRI                                                Sri Lanka         NaN
# SUR                                                 Suriname         NaN
# SWZ                                                Swaziland         NaN
# SYR                                                    Syria         NaN
# TAN                                                 Tanzania         NaN
# TGA                                                    Tonga         NaN
# TKM                                             Turkmenistan         NaN
# UGA                                                   Uganda         NaN
# UAE                                     United Arab Emirates         NaN
# URU                                                  Uruguay         NaN
# VAN                                                  Vanuatu         NaN
# ISV                                          Virgin Islands*         NaN
# YEM                                                    Yemen         NaN
# ZAM                                                   Zambia         NaN
